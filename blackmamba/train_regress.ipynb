# %%
# ===== CONFIGURATION =====
# List of market IDs to train on

market_ids = [253591
    ,253592
    ,253593
    ,253594
    ,253595
    ,253596
    ,253598
    ,253597
    ,253634
    ,253639
    ,253640
    ,253635
    ,253641
    ,253642
    ,253643
    ,253609
    ,253610
    ,253730
    ,253728
    ,253727
    ,253706
    ,253722
    ,253723
    ,253726
    ,253725
    ,253724
    ,253729
    ,253731
    ,253733
    ,253734
    ,253732
    ,253735
    ,253736
    ,253737
    ,511755
    ,511753
    ,511754
    ,538928
    ,538929
    ,538930
    ,538931
    ,538932
    ,538939
    ,538933
    ,538937
    ,538934
    ,538935
    ,538936
    ,538938
    ,253842
    ,253843
    ,253697
    ,253698
    ,253699
    ,253701
    ,253702
    ,253703
    ,253874]
MARKET_IDS = [str(mid) for mid in market_ids]

# Training hyperparameters
D_MODEL = 128
DROPOUT = 0.08
LEARNING_RATE = 2e-4
WEIGHT_DECAY = 3e-3
BATCH_SIZE = 256
EPOCHS = 30
PATIENCE = 7
GRAD_CLIP = 0.7

# Data path
BASE_DIR = "../IEOR4212/exploration/datasets"

# Model selection (set to False to skip)
TRAIN_MAMBA = True
TRAIN_LSTM = True

print(f"Will train on {len(MARKET_IDS)} market(s)")
print(f"Markets: {MARKET_IDS}")
print(f"Train Mamba: {TRAIN_MAMBA} | Train LSTM: {TRAIN_LSTM}")
# Out:
# Will train on 58 market(s)
# Markets: ['253591', '253592', '253593', '253594', '253595', '253596', '253598', '253597', '253634', '253639', '253640', '253635', '253641', '253642', '253643', '253609', '253610', '253730', '253728', '253727', '253706', '253722', '253723', '253726', '253725', '253724', '253729', '253731', '253733', '253734', '253732', '253735', '253736', '253737', '511755', '511753', '511754', '538928', '538929', '538930', '538931', '538932', '538939', '538933', '538937', '538934', '538935', '538936', '538938', '253842', '253843', '253697', '253698', '253699', '253701', '253702', '253703', '253874']
# Train Mamba: True | Train LSTM: True

# %%
import os
import json
from pathlib import Path

import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

from mamba_ssm import Mamba

import sys
import pandas as pd

# Add both datacollection and IEOR4212 to path
datacollection_path = str(Path.cwd().parent.parent / 'datacollection')
ieor4212_path = str(Path.cwd().parent / 'IEOR4212')

sys.path.insert(0, datacollection_path)
sys.path.insert(0, ieor4212_path)
from src.preprocessing.data_prep import load_dataset, pnl_report_for_split

print(f"PyTorch version: {torch.__version__}")
print(f"Device: {'cuda' if torch.cuda.is_available() else 'cpu'}")
# Out:
# PyTorch version: 2.9.1+cu128
# Device: cuda

# %% [markdown]
# ## Model Definition

# %%
class MambaRegressor(nn.Module):
    def __init__(self, d_in: int, d_model: int = 64, dropout: float = 0.1):
        super().__init__()
        self.inp = nn.Linear(d_in, d_model)
        self.mamba = Mamba(d_model=d_model, d_state=16, d_conv=4, expand=2)
        self.drop = nn.Dropout(dropout)
        self.head = nn.Linear(d_model, 1)

    def forward(self, x):
        # x: (B, L, F)
        x = self.inp(x)              # (B, L, d_model)
        x = self.mamba(x)            # (B, L, d_model)
        x = x[:, -1, :]              # last token summary
        x = self.drop(x)
        return self.head(x).squeeze(-1)  # (B,)

print("✓ Model class defined")
# Out:
# ✓ Model class defined

# %%
class LSTMRegressor(nn.Module):
    def __init__(self, d_in: int, d_model: int = 64, dropout: float = 0.1, num_layers: int = 2):
        super().__init__()
        self.lstm = nn.LSTM(
            input_size=d_in,
            hidden_size=d_model,
            num_layers=num_layers,
            dropout=dropout if num_layers > 1 else 0.0,
            batch_first=True
        )
        self.drop = nn.Dropout(dropout)
        self.head = nn.Linear(d_model, 1)

    def forward(self, x):
        # x: (B, L, F)
        out, (h_n, c_n) = self.lstm(x)  # out: (B, L, d_model)
        x = out[:, -1, :]                # last timestep
        x = self.drop(x)
        return self.head(x).squeeze(-1)  # (B,)

print("✓ LSTM model class defined")
# Out:
# ✓ LSTM model class defined

# %% [markdown]
# ## Data Loading

# %%
def load_market_dataset(ds_dir: Path):
    """Load dataset from dir/ or move/ subdirectory."""
    data_path = ds_dir
    
    if not data_path.exists():
        raise FileNotFoundError(f"Dataset path not found: {data_path}")
    
    X_train = np.load(data_path / "X_train.npy").astype(np.float32)
    y_train = np.load(data_path / "y_train.npy").astype(np.float32)
    X_val   = np.load(data_path / "X_val.npy").astype(np.float32)
    y_val   = np.load(data_path / "y_val.npy").astype(np.float32)
    X_test  = np.load(data_path / "X_test.npy").astype(np.float32)
    y_test  = np.load(data_path / "y_test.npy").astype(np.float32)

    end_idx_train = np.load(data_path / "end_idx_train.npy").astype(np.float32)
    end_idx_val   = np.load(data_path / "end_idx_val.npy").astype(np.float32)
    end_idx_test  = np.load(data_path / "end_idx_test.npy").astype(np.float32)

    ev = pd.read_csv(data_path / "ev.csv", index_col=0, parse_dates=True)

    meta = {}
    meta_path = data_path / "metadata.json"
    if meta_path.exists():
        with open(meta_path, "r") as f:
            meta = json.load(f)

    return (X_train, y_train, X_val, y_val, X_test, y_test, meta, ev, end_idx_train, end_idx_val, end_idx_test)

print("✓ Data loading function defined")
# Out:
# ✓ Data loading function defined

# %% [markdown]
# ## Training Functions

# %%
@torch.no_grad()
def eval_regression(model, loader, device):
    """Evaluate regression model: MAE and directional sign accuracy."""
    model.eval()
    preds, ys = [], []
    for xb, yb in loader:
        xb = xb.to(device)
        yb = yb.to(device)
        pr = model(xb)
        preds.append(pr.detach().cpu().numpy())
        ys.append(yb.detach().cpu().numpy())
    p = np.concatenate(preds)
    y = np.concatenate(ys)

    mae = float(np.mean(np.abs(p - y)))
    sign_acc = float(np.mean(np.sign(p) == np.sign(y)))
    return mae, sign_acc

print("✓ Evaluation function defined")
# Out:
# ✓ Evaluation function defined

# %%
def sigmoid(x):
    return 1.0 / (1.0 + np.exp(-x))

def pnl_from_dz_preds(
    ev: pd.DataFrame,
    dz_pred: np.ndarray,
    n_train: int,
    n_val: int,
    n_test: int,
    seq_len: int,
    split: str,
    thr_dp: float = 0.0,
    cost_per_trade: float = 0.0,   # absolute cost in price units (e.g. 0.0005)
):
    """
    Computes 1-step mark-to-market PnL:
      position = sign(predicted dp) if |predicted dp| >= thr_dp else 0
      pnl      = position * (p_next - p_now) - cost_per_trade * |position|

    dz_pred is model output (predicted z_{t+1}-z_t) for the chosen split.

    Assumes dataset windows were made sequentially:
      sample i ends at event index end_idx = (seq_len - 1) + i
      next price is at end_idx + 1
    """

    # choose split ranges in "sample index space"
    if split == "train":
        start_i, end_i = 0, n_train
    elif split == "val":
        start_i, end_i = n_train, n_train + n_val
    elif split == "test":
        start_i, end_i = n_train + n_val, n_train + n_val + n_test
    else:
        raise ValueError("split must be one of: train, val, test")

    dz_pred = np.asarray(dz_pred).reshape(-1)
    dz_pred = dz_pred[: (end_i - start_i)]  # safety

    # map samples -> event indices (where window ends)
    end_idx = (seq_len - 1) + np.arange(start_i, end_i)
    # we need end_idx+1 to exist
    end_idx = end_idx[end_idx + 1 < len(ev)]
    if len(end_idx) == 0:
        return {"n_samples": 0, "n_trades": 0, "trade_rate": 0.0,
                "avg_pnl": 0.0, "sum_pnl": 0.0, "median_pnl": 0.0, "hit_rate_on_trades": 0.0}

    dz_pred = dz_pred[:len(end_idx)]

    p_now  = ev["price"].values[end_idx]
    p_next = ev["price"].values[end_idx + 1]
    z_now  = ev["z"].values[end_idx]

    # convert predicted dz -> predicted dp in price space
    p_pred_next = sigmoid(z_now + dz_pred)
    dp_pred = p_pred_next - p_now

    # trading rule
    pos = np.sign(dp_pred)
    pos[np.abs(dp_pred) < thr_dp] = 0.0

    dp_real = (p_next - p_now)
    pnl = pos * dp_real - cost_per_trade * np.abs(pos)

    n_trades = float(np.sum(pos != 0.0))
    trade_rate = n_trades / float(len(end_idx))

    # "hit rate" only on executed trades
    hit = (pos * dp_real) > 0
    hit_rate = float(np.mean(hit[pos != 0.0])) if n_trades > 0 else 0.0

    return {
        "n_samples": float(len(end_idx)),
        "n_trades": n_trades,
        "trade_rate": float(trade_rate),
        "avg_pnl": float(np.mean(pnl)),
        "sum_pnl": float(np.sum(pnl)),
        "median_pnl": float(np.median(pnl)),
        "hit_rate_on_trades": hit_rate,
    }

def pick_best_threshold_on_val(ev, dz_pred_val, n_train, n_val, n_test, seq_len,
                               thr_grid=(0.0, 0.0005, 0.001, 0.002, 0.005),
                               cost_per_trade=0.0):
    best = None
    for thr in thr_grid:
        stats = pnl_from_dz_preds(ev, dz_pred_val, n_train, n_val, n_test, seq_len,
                                  split="val", thr_dp=thr, cost_per_trade=cost_per_trade)
        if best is None or stats["sum_pnl"] > best["sum_pnl"]:
            best = dict(stats)
            best["thr_dp"] = thr
    return best

print("✓ PnL computation functions defined")
# Out:
# ✓ PnL computation functions defined

# %%
def train_one_market(
    market_id: str,
    base_dir: Path,
    *,
    d_model: int = 64,
    dropout: float = 0.15,
    lr: float = 1e-4,
    weight_decay: float = 5e-2,
    batch_size: int = 256,
    epochs: int = 30,
    patience: int = 5,
    grad_clip: float = 1.0,
):
    """Train Mamba regressor on one market."""
    ds_dir = base_dir / f"market_{market_id}" / "move_reg"
    X_train, y_train, X_val, y_val, X_test, y_test, meta, ev, end_idx_train, end_idx_val, end_idx_test = load_market_dataset(ds_dir)

    if len(X_train) == 0 or len(X_val) == 0:
        raise ValueError(f"Empty train/val in {ds_dir}")

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    d_in = X_train.shape[-1]

    # Get seq_len from metadata
    seq_len = meta.get("seq_len", 64)
    n_train = X_train.shape[0]
    n_val = X_val.shape[0]
    n_test = X_test.shape[0]

    model = MambaRegressor(d_in=d_in, d_model=d_model, dropout=dropout).to(device)

    train_loader = DataLoader(
        TensorDataset(torch.tensor(X_train), torch.tensor(y_train)),
        batch_size=batch_size,
        shuffle=False,
        drop_last=False
    )
    val_loader = DataLoader(
        TensorDataset(torch.tensor(X_val), torch.tensor(y_val)),
        batch_size=batch_size,
        shuffle=False
    )
    test_loader = DataLoader(
        TensorDataset(torch.tensor(X_test), torch.tensor(y_test)),
        batch_size=batch_size,
        shuffle=False
    )

    opt = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
    loss_fn = nn.SmoothL1Loss()  # Huber loss

    best_val = float("inf")
    best_state = None
    bad = 0

    print(f"\n{'='*80}")
    print(f"Training Market: {market_id}")
    print(f"{'='*80}")
    print(f"Shapes: X_train={X_train.shape} X_val={X_val.shape} X_test={X_test.shape}")
    print(f"Features: {d_in} | seq_len: {seq_len}")
    print(f"Device: {device}")
    
    for ep in range(1, epochs + 1):
        model.train()
        losses = []

        for xb, yb in train_loader:
            xb = xb.to(device)
            yb = yb.to(device)

            opt.zero_grad(set_to_none=True)
            pr = model(xb)
            loss = loss_fn(pr, yb)
            loss.backward()
            nn.utils.clip_grad_norm_(model.parameters(), grad_clip)
            opt.step()
            losses.append(loss.item())

        val_mae, val_sign = eval_regression(model, val_loader, device)
        tr_loss = float(np.mean(losses))

        print(f"Epoch {ep:02d}/{epochs} | train_loss={tr_loss:.6f} | val_MAE={val_mae:.6f} | val_sign_acc={val_sign:.3f}", end="")

        if val_mae < best_val - 1e-6:
            best_val = val_mae
            best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
            bad = 0
            print(" ← best")
        else:
            bad += 1
            print()
            if bad >= patience:
                print(f"Early stopping (no val MAE improvement for {patience} epochs).")
                break

    if best_state is not None:
        model.load_state_dict(best_state)
        model.to(device)

    # Final eval
    val_mae, val_sign = eval_regression(model, val_loader, device)
    test_mae, test_sign = eval_regression(model, test_loader, device)

    print(f"\n{'='*80}")
    print(f"FINAL RESULTS:")
    print(f"  Val:  MAE={val_mae:.6f} | Sign Acc={val_sign:.3f}")
    print(f"  Test: MAE={test_mae:.6f} | Sign Acc={test_sign:.3f}")
    print(f"{'='*80}")

    # Get predictions (dz predictions from model)
    @torch.no_grad()
    def predict_numpy(model, X):
        model.eval()
        X_t = torch.tensor(X, dtype=torch.float32, device=device)
        return model(X_t).detach().cpu().numpy()
    
    yhat_val  = predict_numpy(model, X_val)
    yhat_test = predict_numpy(model, X_test)
    
    # ===== CORRECT PnL COMPUTATION IN PRICE SPACE =====
    print(f"\n{'='*80}")
    print(f"PnL Analysis (price-space, mark-to-market)")
    print(f"{'='*80}")
    
    # Find best threshold on validation set
    best = pick_best_threshold_on_val(
        ev,
        dz_pred_val=yhat_val,
        n_train=n_train, n_val=n_val, n_test=n_test,
        seq_len=seq_len,
        thr_grid=(0.0, 0.0005, 0.001, 0.002, 0.005, 0.01),
        cost_per_trade=0.0,   # set to e.g. 0.0005 to model trading costs
    )
    
    thr = best["thr_dp"]
    print(f"\nBest VAL threshold (price space): {thr:.6f}")
    print(f"  sum_pnl={best['sum_pnl']:.6f} | trade_rate={best['trade_rate']:.3f} | hit_rate={best['hit_rate_on_trades']:.3f}")
    
    # Evaluate with best threshold on val and test
    val_stats = pnl_from_dz_preds(
        ev, yhat_val, n_train, n_val, n_test, seq_len, 
        "val", thr_dp=thr, cost_per_trade=0.0
    )
    test_stats = pnl_from_dz_preds(
        ev, yhat_test, n_train, n_val, n_test, seq_len, 
        "test", thr_dp=thr, cost_per_trade=0.0
    )
    
    print(f"\nVAL  PnL: {val_stats}")
    print(f"TEST PnL: {test_stats}")
    print(f"{'='*80}")

    # Save model
    out_dir = ds_dir / "checkpoints"
    out_dir.mkdir(parents=True, exist_ok=True)
    ckpt_path = out_dir / "mamba_regressor.pt"
    
    torch.save({
        "state_dict": model.state_dict(),
        "d_in": d_in,
        "d_model": d_model,
        "dropout": dropout,
        "meta": meta,
        "metrics": {
            "best_val_mae": val_mae,
            "val_sign_acc": val_sign,
            "test_mae": test_mae,
            "test_sign_acc": test_sign,
            "val_pnl": val_stats,
            "test_pnl": test_stats,
            "best_threshold_dp": thr,
        }
    }, ckpt_path)

    with open(out_dir / "metrics.json", "w") as f:
        json.dump({
            "best_val_mae": val_mae,
            "val_sign_acc": val_sign,
            "test_mae": test_mae,
            "test_sign_acc": test_sign,
            "market_id": market_id,
            "val_pnl": val_stats,
            "test_pnl": test_stats,
            "best_threshold_dp": thr,
        }, f, indent=2)
    
    print(f"✓ Model saved to: {ckpt_path}")

    return val_mae, test_mae, val_sign, test_sign, val_stats, test_stats

print("✓ Training function defined")
# Out:
# ✓ Training function defined

# %%
def train_lstm_baseline(
    market_id: str,
    base_dir: Path,
    *,
    d_model: int = 64,
    dropout: float = 0.15,
    lr: float = 1e-4,
    weight_decay: float = 5e-2,
    batch_size: int = 256,
    epochs: int = 30,
    patience: int = 5,
    grad_clip: float = 1.0,
):
    """Train LSTM baseline regressor on one market."""
    ds_dir = base_dir / f"market_{market_id}" / "move_reg"
    X_train, y_train, X_val, y_val, X_test, y_test, meta, ev, end_idx_train, end_idx_val, end_idx_test = load_market_dataset(ds_dir)

    if len(X_train) == 0 or len(X_val) == 0:
        raise ValueError(f"Empty train/val in {ds_dir}")

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    d_in = X_train.shape[-1]

    # Get seq_len from metadata
    seq_len = meta.get("seq_len", 64)
    n_train = X_train.shape[0]
    n_val = X_val.shape[0]
    n_test = X_test.shape[0]

    model = LSTMRegressor(d_in=d_in, d_model=d_model, dropout=dropout, num_layers=2).to(device)

    train_loader = DataLoader(
        TensorDataset(torch.tensor(X_train), torch.tensor(y_train)),
        batch_size=batch_size,
        shuffle=False,
        drop_last=False
    )
    val_loader = DataLoader(
        TensorDataset(torch.tensor(X_val), torch.tensor(y_val)),
        batch_size=batch_size,
        shuffle=False
    )
    test_loader = DataLoader(
        TensorDataset(torch.tensor(X_test), torch.tensor(y_test)),
        batch_size=batch_size,
        shuffle=False
    )

    opt = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
    loss_fn = nn.SmoothL1Loss()  # Huber loss

    best_val = float("inf")
    best_state = None
    bad = 0

    print(f"\n{'='*80}")
    print(f"Training LSTM Baseline: {market_id}")
    print(f"{'='*80}")
    print(f"Shapes: X_train={X_train.shape} X_val={X_val.shape} X_test={X_test.shape}")
    print(f"Features: {d_in} | seq_len: {seq_len}")
    print(f"Device: {device}")
    
    for ep in range(1, epochs + 1):
        model.train()
        losses = []

        for xb, yb in train_loader:
            xb = xb.to(device)
            yb = yb.to(device)

            opt.zero_grad(set_to_none=True)
            pr = model(xb)
            loss = loss_fn(pr, yb)
            loss.backward()
            nn.utils.clip_grad_norm_(model.parameters(), grad_clip)
            opt.step()
            losses.append(loss.item())

        val_mae, val_sign = eval_regression(model, val_loader, device)
        tr_loss = float(np.mean(losses))

        if ep % 5 == 0 or ep == 1:  # Print every 5 epochs to reduce clutter
            print(f"Epoch {ep:02d}/{epochs} | train_loss={tr_loss:.6f} | val_MAE={val_mae:.6f} | val_sign_acc={val_sign:.3f}", end="")

            if val_mae < best_val - 1e-6:
                print(" ← best")
            else:
                print()
        
        if val_mae < best_val - 1e-6:
            best_val = val_mae
            best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
            bad = 0
        else:
            bad += 1
            if bad >= patience:
                print(f"Early stopping (no val MAE improvement for {patience} epochs).")
                break

    if best_state is not None:
        model.load_state_dict(best_state)
        model.to(device)

    # Final eval
    val_mae, val_sign = eval_regression(model, val_loader, device)
    test_mae, test_sign = eval_regression(model, test_loader, device)

    print(f"\n{'='*80}")
    print(f"LSTM FINAL RESULTS:")
    print(f"  Val:  MAE={val_mae:.6f} | Sign Acc={val_sign:.3f}")
    print(f"  Test: MAE={test_mae:.6f} | Sign Acc={test_sign:.3f}")
    print(f"{'='*80}")

    # Get predictions (dz predictions from model)
    @torch.no_grad()
    def predict_numpy(model, X):
        model.eval()
        X_t = torch.tensor(X, dtype=torch.float32, device=device)
        return model(X_t).detach().cpu().numpy()
    
    yhat_val  = predict_numpy(model, X_val)
    yhat_test = predict_numpy(model, X_test)
    
    # ===== PnL COMPUTATION =====
    print(f"\n{'='*80}")
    print(f"LSTM PnL Analysis")
    print(f"{'='*80}")
    
    # Find best threshold on validation set
    best = pick_best_threshold_on_val(
        ev,
        dz_pred_val=yhat_val,
        n_train=n_train, n_val=n_val, n_test=n_test,
        seq_len=seq_len,
        thr_grid=(0.0, 0.0005, 0.001, 0.002, 0.005, 0.01),
        cost_per_trade=0.0,
    )
    
    thr = best["thr_dp"]
    print(f"\nBest VAL threshold: {thr:.6f}")
    print(f"  sum_pnl={best['sum_pnl']:.6f} | trade_rate={best['trade_rate']:.3f} | hit_rate={best['hit_rate_on_trades']:.3f}")
    
    val_stats = pnl_from_dz_preds(
        ev, yhat_val, n_train, n_val, n_test, seq_len, 
        "val", thr_dp=thr, cost_per_trade=0.0
    )
    test_stats = pnl_from_dz_preds(
        ev, yhat_test, n_train, n_val, n_test, seq_len, 
        "test", thr_dp=thr, cost_per_trade=0.0
    )
    
    print(f"\nVAL  PnL: {val_stats}")
    print(f"TEST PnL: {test_stats}")
    print(f"{'='*80}")

    # Save LSTM model
    out_dir = ds_dir / "checkpoints"
    out_dir.mkdir(parents=True, exist_ok=True)
    ckpt_path = out_dir / "lstm_regressor.pt"
    
    torch.save({
        "state_dict": model.state_dict(),
        "d_in": d_in,
        "d_model": d_model,
        "dropout": dropout,
        "meta": meta,
        "metrics": {
            "best_val_mae": val_mae,
            "val_sign_acc": val_sign,
            "test_mae": test_mae,
            "test_sign_acc": test_sign,
            "val_pnl": val_stats,
            "test_pnl": test_stats,
            "best_threshold_dp": thr,
        }
    }, ckpt_path)

    with open(out_dir / "lstm_metrics.json", "w") as f:
        json.dump({
            "best_val_mae": val_mae,
            "val_sign_acc": val_sign,
            "test_mae": test_mae,
            "test_sign_acc": test_sign,
            "market_id": market_id,
            "val_pnl": val_stats,
            "test_pnl": test_stats,
            "best_threshold_dp": thr,
        }, f, indent=2)
    
    print(f"✓ LSTM model saved to: {ckpt_path}")

    return val_mae, test_mae, val_sign, test_sign, val_stats, test_stats

print("✓ LSTM training function defined")
# Out:
# ✓ LSTM training function defined

# %% [markdown]
# ## Train All Markets

# %%
base_dir = Path(BASE_DIR)
mamba_results = []
lstm_results = []

print(f"\nTraining {len(MARKET_IDS)} market(s)...")
print(f"Base directory: {base_dir}")
print(f"Mamba: {'ENABLED' if TRAIN_MAMBA else 'DISABLED'} | LSTM: {'ENABLED' if TRAIN_LSTM else 'DISABLED'}\n")

for market_id in MARKET_IDS:
    print(f"\n{'#'*80}")
    print(f"# Market: {market_id}")
    print(f"{'#'*80}")
    
    # Train Mamba
    if TRAIN_MAMBA:
        try:
            val_mae, test_mae, val_sign, test_sign, val_pnl, test_pnl = train_one_market(
                market_id=market_id,
                base_dir=base_dir,
                d_model=D_MODEL,
                dropout=DROPOUT,
                lr=LEARNING_RATE,
                weight_decay=WEIGHT_DECAY,
                batch_size=BATCH_SIZE,
                epochs=EPOCHS,
                patience=PATIENCE,
                grad_clip=GRAD_CLIP,
            )
            mamba_results.append((market_id, val_mae, test_mae, val_sign, test_sign, val_pnl, test_pnl))
        except Exception as e:
            import traceback
            print(f"\n❌ [SKIP MAMBA] {market_id}")
            print(f"Error: {e}")
            print(f"Traceback:\n{traceback.format_exc()}")
            mamba_results.append((market_id, None, None, None, None, None, None))
    else:
        mamba_results.append((market_id, None, None, None, None, None, None))
    
    # Train LSTM baseline
    if TRAIN_LSTM:
        try:
            val_mae_lstm, test_mae_lstm, val_sign_lstm, test_sign_lstm, val_pnl_lstm, test_pnl_lstm = train_lstm_baseline(
                market_id=market_id,
                base_dir=base_dir,
                d_model=D_MODEL,
                dropout=DROPOUT,
                lr=LEARNING_RATE,
                weight_decay=WEIGHT_DECAY,
                batch_size=BATCH_SIZE,
                epochs=EPOCHS,
                patience=PATIENCE,
                grad_clip=GRAD_CLIP,
            )
            lstm_results.append((market_id, val_mae_lstm, test_mae_lstm, val_sign_lstm, test_sign_lstm, val_pnl_lstm, test_pnl_lstm))
        except Exception as e:
            import traceback
            print(f"\n❌ [SKIP LSTM] {market_id}")
            print(f"Error: {e}")
            print(f"Traceback:\n{traceback.format_exc()}")
            lstm_results.append((market_id, None, None, None, None, None, None))
    else:
        lstm_results.append((market_id, None, None, None, None, None, None))

print(f"\n{'='*80}")
print("ALL TRAINING COMPLETE")
print(f"{'='*80}")
print(f"Mamba: {sum(1 for x in mamba_results if x[1] is not None)}/{len(MARKET_IDS)} successful")
print(f"LSTM:  {sum(1 for x in lstm_results if x[1] is not None)}/{len(MARKET_IDS)} successful")
# Out:
# Training 58 market(s)...
# Base directory: ../IEOR4212/exploration/datasets
# Mamba: ENABLED | LSTM: ENABLED
#
#
# ################################################################################
# # Market: 253591
# ################################################################################
#
# ================================================================================
# Training Market: 253591
# ================================================================================
# Shapes: X_train=(644, 64, 8) X_val=(3985, 64, 8) X_test=(11762, 64, 8)
# Features: 8 | seq_len: 64
# Device: cuda
# Epoch 01/30 | train_loss=0.003122 | val_MAE=0.068760 | val_sign_acc=0.507 ← best
# Epoch 02/30 | train_loss=0.002978 | val_MAE=0.065880 | val_sign_acc=0.507 ← best
# Epoch 01/30 | train_loss=0.003122 | val_MAE=0.068760 | val_sign_acc=0.507 ← best
# Epoch 02/30 | train_loss=0.002978 | val_MAE=0.065880 | val_sign_acc=0.507 ← best
# Epoch 03/30 | train_loss=0.002812 | val_MAE=0.063099 | val_sign_acc=0.507 ← best
# Epoch 04/30 | train_loss=0.002705 | val_MAE=0.060374 | val_sign_acc=0.507 ← best
# Epoch 03/30 | train_loss=0.002812 | val_MAE=0.063099 | val_sign_acc=0.507 ← best
# Epoch 04/30 | train_loss=0.002705 | val_MAE=0.060374 | val_sign_acc=0.507 ← best
# Epoch 05/30 | train_loss=0.002577 | val_MAE=0.057688 | val_sign_acc=0.507 ← best
# Epoch 06/30 | train_loss=0.002459 | val_MAE=0.055032 | val_sign_acc=0.507 ← best
# Epoch 05/30 | train_loss=0.002577 | val_MAE=0.057688 | val_sign_acc=0.507 ← best
# Epoch 06/30 | train_loss=0.002459 | val_MAE=0.055032 | val_sign_acc=0.507 ← best
# Epoch 07/30 | train_loss=0.002321 | val_MAE=0.052397 | val_sign_acc=0.507 ← best
# Epoch 08/30 | train_loss=0.002216 | val_MAE=0.049769 | val_sign_acc=0.507 ← best
# Epoch 07/30 | train_loss=0.002321 | val_MAE=0.052397 | val_sign_acc=0.507 ← best
# Epoch 08/30 | train_loss=0.002216 | val_MAE=0.049769 | val_sign_acc=0.507 ← best
# Epoch 09/30 | train_loss=0.002095 | val_MAE=0.047140 | val_sign_acc=0.507 ← best
# Epoch 10/30 | train_loss=0.001989 | val_MAE=0.044524 | val_sign_acc=0.507 ← best
# Epoch 09/30 | train_loss=0.002095 | val_MAE=0.047140 | val_sign_acc=0.507 ← best
# Epoch 10/30 | train_loss=0.001989 | val_MAE=0.044524 | val_sign_acc=0.507 ← best
# Epoch 11/30 | train_loss=0.001870 | val_MAE=0.041907 | val_sign_acc=0.507 ← best
# Epoch 12/30 | train_loss=0.001788 | val_MAE=0.039286 | val_sign_acc=0.506 ← best
# Epoch 11/30 | train_loss=0.001870 | val_MAE=0.041907 | val_sign_acc=0.507 ← best
# Epoch 12/30 | train_loss=0.001788 | val_MAE=0.039286 | val_sign_acc=0.506 ← best
# Epoch 13/30 | train_loss=0.001673 | val_MAE=0.036669 | val_sign_acc=0.506 ← best
# Epoch 14/30 | train_loss=0.001592 | val_MAE=0.034045 | val_sign_acc=0.506 ← best
# Epoch 13/30 | train_loss=0.001673 | val_MAE=0.036669 | val_sign_acc=0.506 ← best
# Epoch 14/30 | train_loss=0.001592 | val_MAE=0.034045 | val_sign_acc=0.506 ← best
# Epoch 15/30 | train_loss=0.001512 | val_MAE=0.031402 | val_sign_acc=0.506 ← best
# Epoch 16/30 | train_loss=0.001428 | val_MAE=0.028757 | val_sign_acc=0.507 ← best
# Epoch 15/30 | train_loss=0.001512 | val_MAE=0.031402 | val_sign_acc=0.506 ← best
# Epoch 16/30 | train_loss=0.001428 | val_MAE=0.028757 | val_sign_acc=0.507 ← best
# Epoch 17/30 | train_loss=0.001339 | val_MAE=0.026112 | val_sign_acc=0.506 ← best
# Epoch 18/30 | train_loss=0.001251 | val_MAE=0.023472 | val_sign_acc=0.507 ← best
# Epoch 17/30 | train_loss=0.001339 | val_MAE=0.026112 | val_sign_acc=0.506 ← best
# Epoch 18/30 | train_loss=0.001251 | val_MAE=0.023472 | val_sign_acc=0.507 ← best
# Epoch 19/30 | train_loss=0.001197 | val_MAE=0.020854 | val_sign_acc=0.508 ← best
# Epoch 20/30 | train_loss=0.001132 | val_MAE=0.018264 | val_sign_acc=0.507 ← best
# Epoch 19/30 | train_loss=0.001197 | val_MAE=0.020854 | val_sign_acc=0.508 ← best
# Epoch 20/30 | train_loss=0.001132 | val_MAE=0.018264 | val_sign_acc=0.507 ← best
# Epoch 21/30 | train_loss=0.001051 | val_MAE=0.015748 | val_sign_acc=0.509 ← best
# Epoch 22/30 | train_loss=0.001006 | val_MAE=0.013394 | val_sign_acc=0.508 ← best
# Epoch 21/30 | train_loss=0.001051 | val_MAE=0.015748 | val_sign_acc=0.509 ← best
# Epoch 22/30 | train_loss=0.001006 | val_MAE=0.013394 | val_sign_acc=0.508 ← best
# Epoch 23/30 | train_loss=0.000951 | val_MAE=0.011351 | val_sign_acc=0.507 ← best
# Epoch 24/30 | train_loss=0.000897 | val_MAE=0.009859 | val_sign_acc=0.510 ← best
# Epoch 23/30 | train_loss=0.000951 | val_MAE=0.011351 | val_sign_acc=0.507 ← best
# Epoch 24/30 | train_loss=0.000897 | val_MAE=0.009859 | val_sign_acc=0.510 ← best
# Epoch 25/30 | train_loss=0.000851 | val_MAE=0.009291 | val_sign_acc=0.512 ← best
# Epoch 26/30 | train_loss=0.000807 | val_MAE=0.009678 | val_sign_acc=0.498
# Epoch 25/30 | train_loss=0.000851 | val_MAE=0.009291 | val_sign_acc=0.512 ← best
# Epoch 26/30 | train_loss=0.000807 | val_MAE=0.009678 | val_sign_acc=0.498
# Epoch 27/30 | train_loss=0.000777 | val_MAE=0.010799 | val_sign_acc=0.492
# Epoch 28/30 | train_loss=0.000752 | val_MAE=0.012363 | val_sign_acc=0.491
# Epoch 27/30 | train_loss=0.000777 | val_MAE=0.010799 | val_sign_acc=0.492
# Epoch 28/30 | train_loss=0.000752 | val_MAE=0.012363 | val_sign_acc=0.491
# Epoch 29/30 | train_loss=0.000693 | val_MAE=0.014128 | val_sign_acc=0.488
# Epoch 30/30 | train_loss=0.000688 | val_MAE=0.015931 | val_sign_acc=0.486
# Epoch 29/30 | train_loss=0.000693 | val_MAE=0.014128 | val_sign_acc=0.488
# Epoch 30/30 | train_loss=0.000688 | val_MAE=0.015931 | val_sign_acc=0.486
#
# ================================================================================
# FINAL RESULTS:
#   Val:  MAE=0.009291 | Sign Acc=0.512
#   Test: MAE=0.007683 | Sign Acc=0.494
# ================================================================================
#
# ================================================================================
# FINAL RESULTS:
#   Val:  MAE=0.009291 | Sign Acc=0.512
#   Test: MAE=0.007683 | Sign Acc=0.494
# ================================================================================
#
# ================================================================================
# PnL Analysis (price-space, mark-to-market)
# ================================================================================
#
# Best VAL threshold (price space): 0.000000
#   sum_pnl=0.088500 | trade_rate=1.000 | hit_rate=0.512
#
# VAL  PnL: {'n_samples': 3985.0, 'n_trades': 3985.0, 'trade_rate': 1.0, 'avg_pnl': 2.2208281053952577e-05, 'sum_pnl': 0.08850000000000102, 'median_pnl': 0.0004999999999999449, 'hit_rate_on_trades': 0.5124215809284818}
# TEST PnL: {'n_samples': 11761.0, 'n_trades': 11761.0, 'trade_rate': 1.0, 'avg_pnl': -9.990647053822204e-06, 'sum_pnl': -0.11750000000000294, 'median_pnl': -0.0004999999999999449, 'hit_rate_on_trades': 0.4941756653345804}
# ================================================================================
# ✓ Model saved to: ../IEOR4212/exploration/datasets/market_253591/move_reg/checkpoints/mamba_regressor.pt
#
# ================================================================================
# Training LSTM Baseline: 253591
# ================================================================================
# Shapes: X_train=(644, 64, 8) X_val=(3985, 64, 8) X_test=(11762, 64, 8)
# Features: 8 | seq_len: 64
# Device: cuda
#
# ================================================================================
# PnL Analysis (price-space, mark-to-market)
# ================================================================================
#
# Best VAL threshold (price space): 0.000000
#   sum_pnl=0.088500 | trade_rate=1.000 | hit_rate=0.512
#
# VAL  PnL: {'n_samples': 3985.0, 'n_trades': 3985.0, 'trade_rate': 1.0, 'avg_pnl': 2.2208281053952577e-05, 'sum_pnl': 0.08850000000000102, 'median_pnl': 0.0004999999999999449, 'hit_rate_on_trades': 0.5124215809284818}
# TEST PnL: {'n_samples': 11761.0, 'n_trades': 11761.0, 'trade_rate': 1.0, 'avg_pnl': -9.990647053822204e-06, 'sum_pnl': -0.11750000000000294, 'median_pnl': -0.0004999999999999449, 'hit_rate_on_trades': 0.4941756653345804}
# ================================================================================
# ✓ Model saved to: ../IEOR4212/exploration/datasets/market_253591/move_reg/checkpoints/mamba_regressor.pt
#
# ================================================================================
# Training LSTM Baseline: 253591
# ================================================================================
# Shapes: X_train=(644, 64, 8) X_val=(3985, 64, 8) X_test=(11762, 64, 8)
# Features: 8 | seq_len: 64
# Device: cuda
# Epoch 01/30 | train_loss=0.000557 | val_MAE=0.010299 | val_sign_acc=0.512 ← best
# Epoch 01/30 | train_loss=0.000557 | val_MAE=0.010299 | val_sign_acc=0.512 ← best
# Epoch 05/30 | train_loss=0.000526 | val_MAE=0.018004 | val_sign_acc=0.509
# Epoch 05/30 | train_loss=0.000526 | val_MAE=0.018004 | val_sign_acc=0.509
# Early stopping (no val MAE improvement for 7 epochs).
# Early stopping (no val MAE improvement for 7 epochs).
#
# ================================================================================
# LSTM FINAL RESULTS:
#   Val:  MAE=0.010299 | Sign Acc=0.512
#   Test: MAE=0.007218 | Sign Acc=0.510
# ================================================================================
#
# ================================================================================
# LSTM FINAL RESULTS:
#   Val:  MAE=0.010299 | Sign Acc=0.512
#   Test: MAE=0.007218 | Sign Acc=0.510
# ================================================================================
#
# ❌ [SKIP LSTM] 253591
# Error: CUDA out of memory. Tried to allocate 7.67 GiB. GPU 0 has a total capacity of 5.60 GiB of which 4.05 GiB is free. Including non-PyTorch memory, this process has 1.54 GiB memory in use. Of the allocated memory 481.15 MiB is allocated by PyTorch, and 978.85 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Traceback:
# Traceback (most recent call last):
#   File "/tmp/ipykernel_21251/778852393.py", line 42, in <module>
#     val_mae_lstm, test_mae_lstm, val_sign_lstm, test_sign_lstm, val_pnl_lstm, test_pnl_lstm = train_lstm_baseline(
#                                                                                               ~~~~~~~~~~~~~~~~~~~^
#         market_id=market_id,
#         ^^^^^^^^^^^^^^^^^^^^
#     ...<8 lines>...
#         grad_clip=GRAD_CLIP,
#         ^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/tmp/ipykernel_21251/459375583.py", line 122, in train_lstm_baseline
#     yhat_test = predict_numpy(model, X_test)
#   File "/home/omfsv2/Work/mlstats/IEOR_project/.venv/lib/python3.14/site-packages/torch/utils/_contextlib.py", line 120, in decorate_context
#     return func(*args, **kwargs)
#   File "/tmp/ipykernel_21251/459375583.py", line 119, in predict_numpy
#     return model(X_t).detach().cpu().numpy()
#            ~~~~~^^^^^
#   File "/home/omfsv2/Work/mlstats/IEOR_project/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py", line 1775, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/omfsv2/Work/mlstats/IEOR_project/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py", line 1786, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/tmp/ipykernel_21251/102598622.py", line 16, in forward
#     out, (h_n, c_n) = self.lstm(x)  # out: (B, L, d_model)
#                       ~~~~~~~~~^^^
#   File "/home/omfsv2/Work/mlstats/IEOR_project/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py", line 1775, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/omfsv2/Work/mlstats/IEOR_project/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py", line 1786, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/omfsv2/Work/mlstats/IEOR_project/.venv/lib/python3.14/site-packages/torch/nn/modules/rnn.py", line 1127, in forward
#     result = _VF.lstm(
#         input,
#     ...<7 lines>...
#         self.batch_first,
#     )
# torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 7.67 GiB. GPU 0 has a total capacity of 5.60 GiB of which 4.05 GiB is free. Including non-PyTorch memory, this process has 1.54 GiB memory in use. Of the allocated memory 481.15 MiB is allocated by PyTorch, and 978.85 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
#
#
# ################################################################################
# # Market: 253592
# ################################################################################
#
# ================================================================================
# Training Market: 253592
# ================================================================================
# Shapes: X_train=(111, 64, 8) X_val=(74, 64, 8) X_test=(1463, 64, 8)
# Features: 8 | seq_len: 64
# Device: cuda
# Epoch 01/30 | train_loss=0.000988 | val_MAE=0.029461 | val_sign_acc=0.527 ← best
# Epoch 02/30 | train_loss=0.000965 | val_MAE=0.029135 | val_sign_acc=0.527 ← best
# Epoch 03/30 | train_loss=0.000888 | val_MAE=0.028856 | val_sign_acc=0.527 ← best
# Epoch 04/30 | train_loss=0.000895 | val_MAE=0.028630 | val_sign_acc=0.527 ← best
# Epoch 05/30 | train_loss=0.000859 | val_MAE=0.028435 | val_sign_acc=0.527 ← best
# Epoch 06/30 | train_loss=0.000808 | val_MAE=0.028308 | val_sign_acc=0.527 ← best
# Epoch 07/30 | train_loss=0.000771 | val_MAE=0.028210 | val_sign_acc=0.527 ← best
# Epoch 08/30 | train_loss=0.000789 | val_MAE=0.028135 | val_sign_acc=0.527 ← best
# Epoch 09/30 | train_loss=0.000755 | val_MAE=0.028066 | val_sign_acc=0.527 ← best
# Epoch 10/30 | train_loss=0.000745 | val_MAE=0.028022 | val_sign_acc=0.527 ← best
# Epoch 11/30 | train_loss=0.000719 | val_MAE=0.027990 | val_sign_acc=0.527 ← best
# Epoch 12/30 | train_loss=0.000724 | val_MAE=0.027967 | val_sign_acc=0.527 ← best
# Epoch 13/30 | train_loss=0.000687 | val_MAE=0.027945 | val_sign_acc=0.514 ← best
# Epoch 14/30 | train_loss=0.000677 | val_MAE=0.027941 | val_sign_acc=0.514 ← best
# Epoch 15/30 | train_loss=0.000667 | val_MAE=0.027945 | val_sign_acc=0.500
# Epoch 16/30 | train_loss=0.000643 | val_MAE=0.027948 | val_sign_acc=0.500
# Epoch 17/30 | train_loss=0.000626 | val_MAE=0.027946 | val_sign_acc=0.500
#
# ❌ [SKIP LSTM] 253591
# Error: CUDA out of memory. Tried to allocate 7.67 GiB. GPU 0 has a total capacity of 5.60 GiB of which 4.05 GiB is free. Including non-PyTorch memory, this process has 1.54 GiB memory in use. Of the allocated memory 481.15 MiB is allocated by PyTorch, and 978.85 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Traceback:
# Traceback (most recent call last):
#   File "/tmp/ipykernel_21251/778852393.py", line 42, in <module>
#     val_mae_lstm, test_mae_lstm, val_sign_lstm, test_sign_lstm, val_pnl_lstm, test_pnl_lstm = train_lstm_baseline(
#                                                                                               ~~~~~~~~~~~~~~~~~~~^
#         market_id=market_id,
#         ^^^^^^^^^^^^^^^^^^^^
#     ...<8 lines>...
#         grad_clip=GRAD_CLIP,
#         ^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/tmp/ipykernel_21251/459375583.py", line 122, in train_lstm_baseline
#     yhat_test = predict_numpy(model, X_test)
#   File "/home/omfsv2/Work/mlstats/IEOR_project/.venv/lib/python3.14/site-packages/torch/utils/_contextlib.py", line 120, in decorate_context
#     return func(*args, **kwargs)
#   File "/tmp/ipykernel_21251/459375583.py", line 119, in predict_numpy
#     return model(X_t).detach().cpu().numpy()
#            ~~~~~^^^^^
#   File "/home/omfsv2/Work/mlstats/IEOR_project/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py", line 1775, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/omfsv2/Work/mlstats/IEOR_project/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py", line 1786, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/tmp/ipykernel_21251/102598622.py", line 16, in forward
#     out, (h_n, c_n) = self.lstm(x)  # out: (B, L, d_model)
#                       ~~~~~~~~~^^^
#   File "/home/omfsv2/Work/mlstats/IEOR_project/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py", line 1775, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/omfsv2/Work/mlstats/IEOR_project/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py", line 1786, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/omfsv2/Work/mlstats/IEOR_project/.venv/lib/python3.14/site-packages/torch/nn/modules/rnn.py", line 1127, in forward
#     result = _VF.lstm(
#         input,
#     ...<7 lines>...
#         self.batch_first,
#     )
# torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 7.67 GiB. GPU 0 has a total capacity of 5.60 GiB of which 4.05 GiB is free. Including non-PyTorch memory, this process has 1.54 GiB memory in use. Of the allocated memory 481.15 MiB is allocated by PyTorch, and 978.85 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
#
#
# ################################################################################
# # Market: 253592
# ################################################################################
#
# ================================================================================
# Training Market: 253592
# ================================================================================
# Shapes: X_train=(111, 64, 8) X_val=(74, 64, 8) X_test=(1463, 64, 8)
# Features: 8 | seq_len: 64
# Device: cuda
# Epoch 01/30 | train_loss=0.000988 | val_MAE=0.029461 | val_sign_acc=0.527 ← best
# Epoch 02/30 | train_loss=0.000965 | val_MAE=0.029135 | val_sign_acc=0.527 ← best
# Epoch 03/30 | train_loss=0.000888 | val_MAE=0.028856 | val_sign_acc=0.527 ← best
# Epoch 04/30 | train_loss=0.000895 | val_MAE=0.028630 | val_sign_acc=0.527 ← best
# Epoch 05/30 | train_loss=0.000859 | val_MAE=0.028435 | val_sign_acc=0.527 ← best
# Epoch 06/30 | train_loss=0.000808 | val_MAE=0.028308 | val_sign_acc=0.527 ← best
# Epoch 07/30 | train_loss=0.000771 | val_MAE=0.028210 | val_sign_acc=0.527 ← best
# Epoch 08/30 | train_loss=0.000789 | val_MAE=0.028135 | val_sign_acc=0.527 ← best
# Epoch 09/30 | train_loss=0.000755 | val_MAE=0.028066 | val_sign_acc=0.527 ← best
# Epoch 10/30 | train_loss=0.000745 | val_MAE=0.028022 | val_sign_acc=0.527 ← best
# Epoch 11/30 | train_loss=0.000719 | val_MAE=0.027990 | val_sign_acc=0.527 ← best
# Epoch 12/30 | train_loss=0.000724 | val_MAE=0.027967 | val_sign_acc=0.527 ← best
# Epoch 13/30 | train_loss=0.000687 | val_MAE=0.027945 | val_sign_acc=0.514 ← best
# Epoch 14/30 | train_loss=0.000677 | val_MAE=0.027941 | val_sign_acc=0.514 ← best
# Epoch 15/30 | train_loss=0.000667 | val_MAE=0.027945 | val_sign_acc=0.500
# Epoch 16/30 | train_loss=0.000643 | val_MAE=0.027948 | val_sign_acc=0.500
# Epoch 17/30 | train_loss=0.000626 | val_MAE=0.027946 | val_sign_acc=0.500
# Epoch 18/30 | train_loss=0.000614 | val_MAE=0.027950 | val_sign_acc=0.473
# Epoch 19/30 | train_loss=0.000586 | val_MAE=0.027958 | val_sign_acc=0.473
# Epoch 20/30 | train_loss=0.000562 | val_MAE=0.027960 | val_sign_acc=0.432
# Epoch 21/30 | train_loss=0.000592 | val_MAE=0.027955 | val_sign_acc=0.446
# Early stopping (no val MAE improvement for 7 epochs).
#
# ================================================================================
# FINAL RESULTS:
#   Val:  MAE=0.027941 | Sign Acc=0.514
#   Test: MAE=0.073317 | Sign Acc=0.509
# ================================================================================
#
# ================================================================================
# PnL Analysis (price-space, mark-to-market)
# ================================================================================
#
# Best VAL threshold (price space): 0.000000
#   sum_pnl=0.025000 | trade_rate=1.000 | hit_rate=0.514
#
# VAL  PnL: {'n_samples': 74.0, 'n_trades': 74.0, 'trade_rate': 1.0, 'avg_pnl': 0.0003378378378378389, 'sum_pnl': 0.025000000000000078, 'median_pnl': 0.004999999999999977, 'hit_rate_on_trades': 0.5135135135135135}
# TEST PnL: {'n_samples': 1462.0, 'n_trades': 1462.0, 'trade_rate': 1.0, 'avg_pnl': 0.00041757865937072484, 'sum_pnl': 0.6104999999999997, 'median_pnl': 0.0005000000000000004, 'hit_rate_on_trades': 0.5088919288645691}
# ================================================================================
# ✓ Model saved to: ../IEOR4212/exploration/datasets/market_253592/move_reg/checkpoints/mamba_regressor.pt
#
# ================================================================================
# Training LSTM Baseline: 253592
# ================================================================================
# Shapes: X_train=(111, 64, 8) X_val=(74, 64, 8) X_test=(1463, 64, 8)
# Features: 8 | seq_len: 64
# Device: cuda
# Epoch 01/30 | train_loss=0.000702 | val_MAE=0.027961 | val_sign_acc=0.486 ← best
# Epoch 05/30 | train_loss=0.000578 | val_MAE=0.028216 | val_sign_acc=0.473
# Early stopping (no val MAE improvement for 7 epochs).
# Epoch 18/30 | train_loss=0.000614 | val_MAE=0.027950 | val_sign_acc=0.473
# Epoch 19/30 | train_loss=0.000586 | val_MAE=0.027958 | val_sign_acc=0.473
# Epoch 20/30 | train_loss=0.000562 | val_MAE=0.027960 | val_sign_acc=0.432
# Epoch 21/30 | train_loss=0.000592 | val_MAE=0.027955 | val_sign_acc=0.446
# Early stopping (no val MAE improvement for 7 epochs).
#
# ================================================================================
# FINAL RESULTS:
#   Val:  MAE=0.027941 | Sign Acc=0.514
#   Test: MAE=0.073317 | Sign Acc=0.509
# ================================================================================
#
# ================================================================================
# PnL Analysis (price-space, mark-to-market)
# ================================================================================
#
# Best VAL threshold (price space): 0.000000
#   sum_pnl=0.025000 | trade_rate=1.000 | hit_rate=0.514
#
# VAL  PnL: {'n_samples': 74.0, 'n_trades': 74.0, 'trade_rate': 1.0, 'avg_pnl': 0.0003378378378378389, 'sum_pnl': 0.025000000000000078, 'median_pnl': 0.004999999999999977, 'hit_rate_on_trades': 0.5135135135135135}
# TEST PnL: {'n_samples': 1462.0, 'n_trades': 1462.0, 'trade_rate': 1.0, 'avg_pnl': 0.00041757865937072484, 'sum_pnl': 0.6104999999999997, 'median_pnl': 0.0005000000000000004, 'hit_rate_on_trades': 0.5088919288645691}
# ================================================================================
# ✓ Model saved to: ../IEOR4212/exploration/datasets/market_253592/move_reg/checkpoints/mamba_regressor.pt
#
# ================================================================================
# Training LSTM Baseline: 253592
# ================================================================================
# Shapes: X_train=(111, 64, 8) X_val=(74, 64, 8) X_test=(1463, 64, 8)
# Features: 8 | seq_len: 64
# Device: cuda
# Epoch 01/30 | train_loss=0.000702 | val_MAE=0.027961 | val_sign_acc=0.486 ← best
# Epoch 05/30 | train_loss=0.000578 | val_MAE=0.028216 | val_sign_acc=0.473
# Early stopping (no val MAE improvement for 7 epochs).
#
# ================================================================================
# LSTM FINAL RESULTS:
#   Val:  MAE=0.027961 | Sign Acc=0.486
#   Test: MAE=0.078690 | Sign Acc=0.504
# ================================================================================
#
# ================================================================================
# LSTM PnL Analysis
# ================================================================================
#
# Best VAL threshold: 0.005000
#   sum_pnl=0.000000 | trade_rate=0.000 | hit_rate=0.000
#
# VAL  PnL: {'n_samples': 74.0, 'n_trades': 0.0, 'trade_rate': 0.0, 'avg_pnl': 0.0, 'sum_pnl': 0.0, 'median_pnl': 0.0, 'hit_rate_on_trades': 0.0}
# TEST PnL: {'n_samples': 1462.0, 'n_trades': 1210.0, 'trade_rate': 0.8276333789329685, 'avg_pnl': 0.00010259917920656632, 'sum_pnl': 0.14999999999999997, 'median_pnl': 0.0, 'hit_rate_on_trades': 0.5057851239669422}
# ================================================================================
# ✓ LSTM model saved to: ../IEOR4212/exploration/datasets/market_253592/move_reg/checkpoints/lstm_regressor.pt
#
# ################################################################################
# # Market: 253593
# ################################################################################
#
# ================================================================================
# Training Market: 253593
# ================================================================================
# Shapes: X_train=(480, 64, 8) X_val=(275, 64, 8) X_test=(142, 64, 8)
# Features: 8 | seq_len: 64
# Device: cuda
# Epoch 01/30 | train_loss=0.009810 | val_MAE=0.304847 | val_sign_acc=0.564 ← best
# Epoch 02/30 | train_loss=0.009763 | val_MAE=0.303690 | val_sign_acc=0.593 ← best
# Epoch 03/30 | train_loss=0.009640 | val_MAE=0.302533 | val_sign_acc=0.625 ← best
#
# ================================================================================
# LSTM FINAL RESULTS:
#   Val:  MAE=0.027961 | Sign Acc=0.486
#   Test: MAE=0.078690 | Sign Acc=0.504
# ================================================================================
#
# ================================================================================
# LSTM PnL Analysis
# ================================================================================
#
# Best VAL threshold: 0.005000
#   sum_pnl=0.000000 | trade_rate=0.000 | hit_rate=0.000
#
# VAL  PnL: {'n_samples': 74.0, 'n_trades': 0.0, 'trade_rate': 0.0, 'avg_pnl': 0.0, 'sum_pnl': 0.0, 'median_pnl': 0.0, 'hit_rate_on_trades': 0.0}
# TEST PnL: {'n_samples': 1462.0, 'n_trades': 1210.0, 'trade_rate': 0.8276333789329685, 'avg_pnl': 0.00010259917920656632, 'sum_pnl': 0.14999999999999997, 'median_pnl': 0.0, 'hit_rate_on_trades': 0.5057851239669422}
# ================================================================================
# ✓ LSTM model saved to: ../IEOR4212/exploration/datasets/market_253592/move_reg/checkpoints/lstm_regressor.pt
#
# ################################################################################
# # Market: 253593
# ################################################################################
#
# ================================================================================
# Training Market: 253593
# ================================================================================
# Shapes: X_train=(480, 64, 8) X_val=(275, 64, 8) X_test=(142, 64, 8)
# Features: 8 | seq_len: 64
# Device: cuda
# Epoch 01/30 | train_loss=0.009810 | val_MAE=0.304847 | val_sign_acc=0.564 ← best
# Epoch 02/30 | train_loss=0.009763 | val_MAE=0.303690 | val_sign_acc=0.593 ← best
# Epoch 03/30 | train_loss=0.009640 | val_MAE=0.302533 | val_sign_acc=0.625 ← best
# Epoch 04/30 | train_loss=0.009616 | val_MAE=0.301379 | val_sign_acc=0.665 ← best
# Epoch 05/30 | train_loss=0.009555 | val_MAE=0.300230 | val_sign_acc=0.724 ← best
# Epoch 06/30 | train_loss=0.009446 | val_MAE=0.299087 | val_sign_acc=0.760 ← best
# Epoch 07/30 | train_loss=0.009453 | val_MAE=0.297949 | val_sign_acc=0.778 ← best
# Epoch 08/30 | train_loss=0.009407 | val_MAE=0.296819 | val_sign_acc=0.804 ← best
# Epoch 04/30 | train_loss=0.009616 | val_MAE=0.301379 | val_sign_acc=0.665 ← best
# Epoch 05/30 | train_loss=0.009555 | val_MAE=0.300230 | val_sign_acc=0.724 ← best
# Epoch 06/30 | train_loss=0.009446 | val_MAE=0.299087 | val_sign_acc=0.760 ← best
# Epoch 07/30 | train_loss=0.009453 | val_MAE=0.297949 | val_sign_acc=0.778 ← best
# Epoch 08/30 | train_loss=0.009407 | val_MAE=0.296819 | val_sign_acc=0.804 ← best
# Epoch 09/30 | train_loss=0.009376 | val_MAE=0.295696 | val_sign_acc=0.811 ← best
# Epoch 10/30 | train_loss=0.009328 | val_MAE=0.294576 | val_sign_acc=0.825 ← best
# Epoch 11/30 | train_loss=0.009248 | val_MAE=0.293462 | val_sign_acc=0.833 ← best
# Epoch 12/30 | train_loss=0.009242 | val_MAE=0.292355 | val_sign_acc=0.836 ← best
# Epoch 13/30 | train_loss=0.009230 | val_MAE=0.291255 | val_sign_acc=0.844 ← best
# Epoch 09/30 | train_loss=0.009376 | val_MAE=0.295696 | val_sign_acc=0.811 ← best
# Epoch 10/30 | train_loss=0.009328 | val_MAE=0.294576 | val_sign_acc=0.825 ← best
# Epoch 11/30 | train_loss=0.009248 | val_MAE=0.293462 | val_sign_acc=0.833 ← best
# Epoch 12/30 | train_loss=0.009242 | val_MAE=0.292355 | val_sign_acc=0.836 ← best
# Epoch 13/30 | train_loss=0.009230 | val_MAE=0.291255 | val_sign_acc=0.844 ← best
# Epoch 14/30 | train_loss=0.009172 | val_MAE=0.290159 | val_sign_acc=0.847 ← best
# Epoch 15/30 | train_loss=0.009147 | val_MAE=0.289069 | val_sign_acc=0.844 ← best
# Epoch 16/30 | train_loss=0.009164 | val_MAE=0.287988 | val_sign_acc=0.844 ← best
# Epoch 17/30 | train_loss=0.009061 | val_MAE=0.286915 | val_sign_acc=0.847 ← best
# Epoch 18/30 | train_loss=0.009056 | val_MAE=0.285853 | val_sign_acc=0.847 ← best
# Epoch 14/30 | train_loss=0.009172 | val_MAE=0.290159 | val_sign_acc=0.847 ← best
# Epoch 15/30 | train_loss=0.009147 | val_MAE=0.289069 | val_sign_acc=0.844 ← best
# Epoch 16/30 | train_loss=0.009164 | val_MAE=0.287988 | val_sign_acc=0.844 ← best
# Epoch 17/30 | train_loss=0.009061 | val_MAE=0.286915 | val_sign_acc=0.847 ← best
# Epoch 18/30 | train_loss=0.009056 | val_MAE=0.285853 | val_sign_acc=0.847 ← best
# Epoch 19/30 | train_loss=0.009060 | val_MAE=0.284799 | val_sign_acc=0.847 ← best
# Epoch 20/30 | train_loss=0.009056 | val_MAE=0.283750 | val_sign_acc=0.851 ← best
# Epoch 21/30 | train_loss=0.008952 | val_MAE=0.282709 | val_sign_acc=0.851 ← best
# Epoch 22/30 | train_loss=0.008982 | val_MAE=0.281676 | val_sign_acc=0.851 ← best
# Epoch 23/30 | train_loss=0.008932 | val_MAE=0.280651 | val_sign_acc=0.847 ← best
# Epoch 19/30 | train_loss=0.009060 | val_MAE=0.284799 | val_sign_acc=0.847 ← best
# Epoch 20/30 | train_loss=0.009056 | val_MAE=0.283750 | val_sign_acc=0.851 ← best
# Epoch 21/30 | train_loss=0.008952 | val_MAE=0.282709 | val_sign_acc=0.851 ← best
# Epoch 22/30 | train_loss=0.008982 | val_MAE=0.281676 | val_sign_acc=0.851 ← best
# Epoch 23/30 | train_loss=0.008932 | val_MAE=0.280651 | val_sign_acc=0.847 ← best
# Epoch 24/30 | train_loss=0.008889 | val_MAE=0.279638 | val_sign_acc=0.847 ← best
# Epoch 25/30 | train_loss=0.008891 | val_MAE=0.278631 | val_sign_acc=0.847 ← best
# Epoch 26/30 | train_loss=0.008854 | val_MAE=0.277624 | val_sign_acc=0.847 ← best
# Epoch 27/30 | train_loss=0.008853 | val_MAE=0.276616 | val_sign_acc=0.840 ← best
# Epoch 28/30 | train_loss=0.008814 | val_MAE=0.275617 | val_sign_acc=0.840 ← best
# Epoch 24/30 | train_loss=0.008889 | val_MAE=0.279638 | val_sign_acc=0.847 ← best
# Epoch 25/30 | train_loss=0.008891 | val_MAE=0.278631 | val_sign_acc=0.847 ← best
# Epoch 26/30 | train_loss=0.008854 | val_MAE=0.277624 | val_sign_acc=0.847 ← best
# Epoch 27/30 | train_loss=0.008853 | val_MAE=0.276616 | val_sign_acc=0.840 ← best
# Epoch 28/30 | train_loss=0.008814 | val_MAE=0.275617 | val_sign_acc=0.840 ← best
# Epoch 29/30 | train_loss=0.008780 | val_MAE=0.274624 | val_sign_acc=0.840 ← best
# Epoch 30/30 | train_loss=0.008776 | val_MAE=0.273639 | val_sign_acc=0.840 ← best
#
# ================================================================================
# FINAL RESULTS:
#   Val:  MAE=0.273639 | Sign Acc=0.840
#   Test: MAE=0.331463 | Sign Acc=0.754
# ================================================================================
#
# ================================================================================
# PnL Analysis (price-space, mark-to-market)
# ================================================================================
#
# Best VAL threshold (price space): 0.000000
#   sum_pnl=0.097500 | trade_rate=1.000 | hit_rate=0.840
#
# VAL  PnL: {'n_samples': 275.0, 'n_trades': 275.0, 'trade_rate': 1.0, 'avg_pnl': 0.00035454545454545455, 'sum_pnl': 0.0975, 'median_pnl': 0.0005, 'hit_rate_on_trades': 0.84}
# TEST PnL: {'n_samples': 141.0, 'n_trades': 141.0, 'trade_rate': 1.0, 'avg_pnl': 0.0003865248226950355, 'sum_pnl': 0.0545, 'median_pnl': 0.0005, 'hit_rate_on_trades': 0.7588652482269503}
# ================================================================================
# ✓ Model saved to: ../IEOR4212/exploration/datasets/market_253593/move_reg/checkpoints/mamba_regressor.pt
#
# ================================================================================
# Training LSTM Baseline: 253593
# ================================================================================
# Shapes: X_train=(480, 64, 8) X_val=(275, 64, 8) X_test=(142, 64, 8)
# Features: 8 | seq_len: 64
# Device: cuda
# Epoch 01/30 | train_loss=0.012810 | val_MAE=0.306710 | val_sign_acc=0.505 ← best
# Epoch 29/30 | train_loss=0.008780 | val_MAE=0.274624 | val_sign_acc=0.840 ← best
# Epoch 30/30 | train_loss=0.008776 | val_MAE=0.273639 | val_sign_acc=0.840 ← best
#
# ================================================================================
# FINAL RESULTS:
#   Val:  MAE=0.273639 | Sign Acc=0.840
#   Test: MAE=0.331463 | Sign Acc=0.754
# ================================================================================
#
# ================================================================================
# PnL Analysis (price-space, mark-to-market)
# ================================================================================
#
# Best VAL threshold (price space): 0.000000
#   sum_pnl=0.097500 | trade_rate=1.000 | hit_rate=0.840
#
# VAL  PnL: {'n_samples': 275.0, 'n_trades': 275.0, 'trade_rate': 1.0, 'avg_pnl': 0.00035454545454545455, 'sum_pnl': 0.0975, 'median_pnl': 0.0005, 'hit_rate_on_trades': 0.84}
# TEST PnL: {'n_samples': 141.0, 'n_trades': 141.0, 'trade_rate': 1.0, 'avg_pnl': 0.0003865248226950355, 'sum_pnl': 0.0545, 'median_pnl': 0.0005, 'hit_rate_on_trades': 0.7588652482269503}
# ================================================================================
# ✓ Model saved to: ../IEOR4212/exploration/datasets/market_253593/move_reg/checkpoints/mamba_regressor.pt
#
# ================================================================================
# Training LSTM Baseline: 253593
# ================================================================================
# Shapes: X_train=(480, 64, 8) X_val=(275, 64, 8) X_test=(142, 64, 8)
# Features: 8 | seq_len: 64
# Device: cuda
# Epoch 01/30 | train_loss=0.012810 | val_MAE=0.306710 | val_sign_acc=0.505 ← best
# Epoch 05/30 | train_loss=0.012054 | val_MAE=0.306787 | val_sign_acc=0.505
# Early stopping (no val MAE improvement for 7 epochs).
#
# ================================================================================
# LSTM FINAL RESULTS:
#   Val:  MAE=0.306710 | Sign Acc=0.505
#   Test: MAE=0.364242 | Sign Acc=0.465
# ================================================================================
#
# ================================================================================
# LSTM PnL Analysis
# ================================================================================
#
# Best VAL threshold: 0.000000
#   sum_pnl=0.002500 | trade_rate=1.000 | hit_rate=0.505
#
# VAL  PnL: {'n_samples': 275.0, 'n_trades': 275.0, 'trade_rate': 1.0, 'avg_pnl': 9.090909090909091e-06, 'sum_pnl': 0.0025, 'median_pnl': 0.0004999999999999996, 'hit_rate_on_trades': 0.5054545454545455}
# TEST PnL: {'n_samples': 141.0, 'n_trades': 141.0, 'trade_rate': 1.0, 'avg_pnl': -1.773049645390071e-05, 'sum_pnl': -0.0025, 'median_pnl': -0.0005, 'hit_rate_on_trades': 0.46808510638297873}
# ================================================================================
# ✓ LSTM model saved to: ../IEOR4212/exploration/datasets/market_253593/move_reg/checkpoints/lstm_regressor.pt
#
# ################################################################################
# # Market: 253594
# ################################################################################
#
# ================================================================================
# Training Market: 253594
# ================================================================================
# Shapes: X_train=(343, 64, 8) X_val=(315, 64, 8) X_test=(3132, 64, 8)
# Features: 8 | seq_len: 64
# Device: cuda
# Epoch 01/30 | train_loss=0.001543 | val_MAE=0.079522 | val_sign_acc=0.524 ← best
# Epoch 05/30 | train_loss=0.012054 | val_MAE=0.306787 | val_sign_acc=0.505
# Early stopping (no val MAE improvement for 7 epochs).
#
# ================================================================================
# LSTM FINAL RESULTS:
#   Val:  MAE=0.306710 | Sign Acc=0.505
#   Test: MAE=0.364242 | Sign Acc=0.465
# ================================================================================
#
# ================================================================================
# LSTM PnL Analysis
# ================================================================================
#
# Best VAL threshold: 0.000000
#   sum_pnl=0.002500 | trade_rate=1.000 | hit_rate=0.505
#
# VAL  PnL: {'n_samples': 275.0, 'n_trades': 275.0, 'trade_rate': 1.0, 'avg_pnl': 9.090909090909091e-06, 'sum_pnl': 0.0025, 'median_pnl': 0.0004999999999999996, 'hit_rate_on_trades': 0.5054545454545455}
# TEST PnL: {'n_samples': 141.0, 'n_trades': 141.0, 'trade_rate': 1.0, 'avg_pnl': -1.773049645390071e-05, 'sum_pnl': -0.0025, 'median_pnl': -0.0005, 'hit_rate_on_trades': 0.46808510638297873}
# ================================================================================
# ✓ LSTM model saved to: ../IEOR4212/exploration/datasets/market_253593/move_reg/checkpoints/lstm_regressor.pt
#
# ################################################################################
# # Market: 253594
# ################################################################################
#
# ================================================================================
# Training Market: 253594
# ================================================================================
# Shapes: X_train=(343, 64, 8) X_val=(315, 64, 8) X_test=(3132, 64, 8)
# Features: 8 | seq_len: 64
# Device: cuda
# Epoch 01/30 | train_loss=0.001543 | val_MAE=0.079522 | val_sign_acc=0.524 ← best
# Epoch 02/30 | train_loss=0.001519 | val_MAE=0.079397 | val_sign_acc=0.524 ← best
# Epoch 03/30 | train_loss=0.001466 | val_MAE=0.079253 | val_sign_acc=0.521 ← best
# Epoch 04/30 | train_loss=0.001475 | val_MAE=0.079103 | val_sign_acc=0.511 ← best
# Epoch 05/30 | train_loss=0.001403 | val_MAE=0.078952 | val_sign_acc=0.508 ← best
# Epoch 06/30 | train_loss=0.001419 | val_MAE=0.078796 | val_sign_acc=0.524 ← best
# Epoch 07/30 | train_loss=0.001383 | val_MAE=0.078634 | val_sign_acc=0.527 ← best
# Epoch 02/30 | train_loss=0.001519 | val_MAE=0.079397 | val_sign_acc=0.524 ← best
# Epoch 03/30 | train_loss=0.001466 | val_MAE=0.079253 | val_sign_acc=0.521 ← best
# Epoch 04/30 | train_loss=0.001475 | val_MAE=0.079103 | val_sign_acc=0.511 ← best
# Epoch 05/30 | train_loss=0.001403 | val_MAE=0.078952 | val_sign_acc=0.508 ← best
# Epoch 06/30 | train_loss=0.001419 | val_MAE=0.078796 | val_sign_acc=0.524 ← best
# Epoch 07/30 | train_loss=0.001383 | val_MAE=0.078634 | val_sign_acc=0.527 ← best
# Epoch 08/30 | train_loss=0.001370 | val_MAE=0.078467 | val_sign_acc=0.530 ← best
# Epoch 09/30 | train_loss=0.001338 | val_MAE=0.078301 | val_sign_acc=0.527 ← best
# Epoch 10/30 | train_loss=0.001298 | val_MAE=0.078138 | val_sign_acc=0.530 ← best
# Epoch 11/30 | train_loss=0.001299 | val_MAE=0.077974 | val_sign_acc=0.533 ← best
# Epoch 12/30 | train_loss=0.001283 | val_MAE=0.077801 | val_sign_acc=0.530 ← best
# Epoch 13/30 | train_loss=0.001298 | val_MAE=0.077622 | val_sign_acc=0.530 ← best
# Epoch 08/30 | train_loss=0.001370 | val_MAE=0.078467 | val_sign_acc=0.530 ← best
# Epoch 09/30 | train_loss=0.001338 | val_MAE=0.078301 | val_sign_acc=0.527 ← best
# Epoch 10/30 | train_loss=0.001298 | val_MAE=0.078138 | val_sign_acc=0.530 ← best
# Epoch 11/30 | train_loss=0.001299 | val_MAE=0.077974 | val_sign_acc=0.533 ← best
# Epoch 12/30 | train_loss=0.001283 | val_MAE=0.077801 | val_sign_acc=0.530 ← best
# Epoch 13/30 | train_loss=0.001298 | val_MAE=0.077622 | val_sign_acc=0.530 ← best
# Epoch 14/30 | train_loss=0.001279 | val_MAE=0.077443 | val_sign_acc=0.546 ← best
# Epoch 15/30 | train_loss=0.001271 | val_MAE=0.077271 | val_sign_acc=0.559 ← best
# Epoch 16/30 | train_loss=0.001232 | val_MAE=0.077110 | val_sign_acc=0.568 ← best
# Epoch 17/30 | train_loss=0.001259 | val_MAE=0.076958 | val_sign_acc=0.581 ← best
# Epoch 18/30 | train_loss=0.001230 | val_MAE=0.076810 | val_sign_acc=0.600 ← best
# Epoch 19/30 | train_loss=0.001221 | val_MAE=0.076665 | val_sign_acc=0.622 ← best
# Epoch 14/30 | train_loss=0.001279 | val_MAE=0.077443 | val_sign_acc=0.546 ← best
# Epoch 15/30 | train_loss=0.001271 | val_MAE=0.077271 | val_sign_acc=0.559 ← best
# Epoch 16/30 | train_loss=0.001232 | val_MAE=0.077110 | val_sign_acc=0.568 ← best
# Epoch 17/30 | train_loss=0.001259 | val_MAE=0.076958 | val_sign_acc=0.581 ← best
# Epoch 18/30 | train_loss=0.001230 | val_MAE=0.076810 | val_sign_acc=0.600 ← best
# Epoch 19/30 | train_loss=0.001221 | val_MAE=0.076665 | val_sign_acc=0.622 ← best
# Epoch 20/30 | train_loss=0.001226 | val_MAE=0.076520 | val_sign_acc=0.651 ← best
# Epoch 21/30 | train_loss=0.001226 | val_MAE=0.076380 | val_sign_acc=0.660 ← best
# Epoch 22/30 | train_loss=0.001177 | val_MAE=0.076236 | val_sign_acc=0.679 ← best
# Epoch 23/30 | train_loss=0.001209 | val_MAE=0.076086 | val_sign_acc=0.695 ← best
# Epoch 24/30 | train_loss=0.001181 | val_MAE=0.075941 | val_sign_acc=0.705 ← best
# Epoch 25/30 | train_loss=0.001166 | val_MAE=0.075807 | val_sign_acc=0.711 ← best
# Epoch 20/30 | train_loss=0.001226 | val_MAE=0.076520 | val_sign_acc=0.651 ← best
# Epoch 21/30 | train_loss=0.001226 | val_MAE=0.076380 | val_sign_acc=0.660 ← best
# Epoch 22/30 | train_loss=0.001177 | val_MAE=0.076236 | val_sign_acc=0.679 ← best
# Epoch 23/30 | train_loss=0.001209 | val_MAE=0.076086 | val_sign_acc=0.695 ← best
# Epoch 24/30 | train_loss=0.001181 | val_MAE=0.075941 | val_sign_acc=0.705 ← best
# Epoch 25/30 | train_loss=0.001166 | val_MAE=0.075807 | val_sign_acc=0.711 ← best
# Epoch 26/30 | train_loss=0.001168 | val_MAE=0.075677 | val_sign_acc=0.717 ← best
# Epoch 27/30 | train_loss=0.001168 | val_MAE=0.075546 | val_sign_acc=0.721 ← best
# Epoch 28/30 | train_loss=0.001176 | val_MAE=0.075409 | val_sign_acc=0.714 ← best
# Epoch 29/30 | train_loss=0.001177 | val_MAE=0.075266 | val_sign_acc=0.721 ← best
# Epoch 30/30 | train_loss=0.001162 | val_MAE=0.075128 | val_sign_acc=0.717 ← best
# Epoch 26/30 | train_loss=0.001168 | val_MAE=0.075677 | val_sign_acc=0.717 ← best
# Epoch 27/30 | train_loss=0.001168 | val_MAE=0.075546 | val_sign_acc=0.721 ← best
# Epoch 28/30 | train_loss=0.001176 | val_MAE=0.075409 | val_sign_acc=0.714 ← best
# Epoch 29/30 | train_loss=0.001177 | val_MAE=0.075266 | val_sign_acc=0.721 ← best
# Epoch 30/30 | train_loss=0.001162 | val_MAE=0.075128 | val_sign_acc=0.717 ← best
#
# ================================================================================
# FINAL RESULTS:
#   Val:  MAE=0.075128 | Sign Acc=0.717
#   Test: MAE=0.064360 | Sign Acc=0.529
# ================================================================================
#
# ================================================================================
# PnL Analysis (price-space, mark-to-market)
# ================================================================================
#
# Best VAL threshold (price space): 0.000000
#   sum_pnl=0.071500 | trade_rate=1.000 | hit_rate=0.717
#
# VAL  PnL: {'n_samples': 315.0, 'n_trades': 315.0, 'trade_rate': 1.0, 'avg_pnl': 0.00022698412698412678, 'sum_pnl': 0.07149999999999994, 'median_pnl': 0.0004999999999999987, 'hit_rate_on_trades': 0.7174603174603175}
# TEST PnL: {'n_samples': 3131.0, 'n_trades': 3131.0, 'trade_rate': 1.0, 'avg_pnl': -2.634940913446185e-05, 'sum_pnl': -0.08250000000000005, 'median_pnl': 0.0004999999999999987, 'hit_rate_on_trades': 0.5292238901309486}
# ================================================================================
# ✓ Model saved to: ../IEOR4212/exploration/datasets/market_253594/move_reg/checkpoints/mamba_regressor.pt
#
# ================================================================================
# Training LSTM Baseline: 253594
# ================================================================================
# Shapes: X_train=(343, 64, 8) X_val=(315, 64, 8) X_test=(3132, 64, 8)
# Features: 8 | seq_len: 64
# Device: cuda
# Epoch 01/30 | train_loss=0.003662 | val_MAE=0.112040 | val_sign_acc=0.517 ← best
#
# ================================================================================
# FINAL RESULTS:
#   Val:  MAE=0.075128 | Sign Acc=0.717
#   Test: MAE=0.064360 | Sign Acc=0.529
# ================================================================================
#
# ================================================================================
# PnL Analysis (price-space, mark-to-market)
# ================================================================================
#
# Best VAL threshold (price space): 0.000000
#   sum_pnl=0.071500 | trade_rate=1.000 | hit_rate=0.717
#
# VAL  PnL: {'n_samples': 315.0, 'n_trades': 315.0, 'trade_rate': 1.0, 'avg_pnl': 0.00022698412698412678, 'sum_pnl': 0.07149999999999994, 'median_pnl': 0.0004999999999999987, 'hit_rate_on_trades': 0.7174603174603175}
# TEST PnL: {'n_samples': 3131.0, 'n_trades': 3131.0, 'trade_rate': 1.0, 'avg_pnl': -2.634940913446185e-05, 'sum_pnl': -0.08250000000000005, 'median_pnl': 0.0004999999999999987, 'hit_rate_on_trades': 0.5292238901309486}
# ================================================================================
# ✓ Model saved to: ../IEOR4212/exploration/datasets/market_253594/move_reg/checkpoints/mamba_regressor.pt
#
# ================================================================================
# Training LSTM Baseline: 253594
# ================================================================================
# Shapes: X_train=(343, 64, 8) X_val=(315, 64, 8) X_test=(3132, 64, 8)
# Features: 8 | seq_len: 64
# Device: cuda
# Epoch 01/30 | train_loss=0.003662 | val_MAE=0.112040 | val_sign_acc=0.517 ← best
# Epoch 05/30 | train_loss=0.002898 | val_MAE=0.100878 | val_sign_acc=0.517 ← best
# Epoch 10/30 | train_loss=0.002223 | val_MAE=0.088755 | val_sign_acc=0.517 ← best
# Epoch 05/30 | train_loss=0.002898 | val_MAE=0.100878 | val_sign_acc=0.517 ← best
# Epoch 10/30 | train_loss=0.002223 | val_MAE=0.088755 | val_sign_acc=0.517 ← best
# Epoch 15/30 | train_loss=0.001763 | val_MAE=0.080172 | val_sign_acc=0.517 ← best
# Epoch 20/30 | train_loss=0.001533 | val_MAE=0.077411 | val_sign_acc=0.517
# Epoch 15/30 | train_loss=0.001763 | val_MAE=0.080172 | val_sign_acc=0.517 ← best
# Epoch 20/30 | train_loss=0.001533 | val_MAE=0.077411 | val_sign_acc=0.517
# Epoch 25/30 | train_loss=0.001384 | val_MAE=0.077691 | val_sign_acc=0.517
# Early stopping (no val MAE improvement for 7 epochs).
#
# ================================================================================
# LSTM FINAL RESULTS:
#   Val:  MAE=0.077381 | Sign Acc=0.517
#   Test: MAE=0.069023 | Sign Acc=0.536
# ================================================================================
#
# ================================================================================
# LSTM PnL Analysis
# ================================================================================
#
# Best VAL threshold: 0.000500
#   sum_pnl=0.001000 | trade_rate=0.019 | hit_rate=0.667
#
# VAL  PnL: {'n_samples': 315.0, 'n_trades': 6.0, 'trade_rate': 0.01904761904761905, 'avg_pnl': 3.174603174603172e-06, 'sum_pnl': 0.0009999999999999992, 'median_pnl': 0.0, 'hit_rate_on_trades': 0.6666666666666666}
# TEST PnL: {'n_samples': 3131.0, 'n_trades': 2345.0, 'trade_rate': 0.7489619929734909, 'avg_pnl': 2.6030022357074413e-05, 'sum_pnl': 0.08149999999999999, 'median_pnl': 0.0, 'hit_rate_on_trades': 0.553091684434968}
# ================================================================================
# ✓ LSTM model saved to: ../IEOR4212/exploration/datasets/market_253594/move_reg/checkpoints/lstm_regressor.pt
#
# ################################################################################
# # Market: 253595
# ################################################################################
# ...
# Epoch 05/30 | train_loss=0.001126 | val_MAE=0.033200 | val_sign_acc=0.517 ← best
# Epoch 06/30 | train_loss=0.001021 | val_MAE=0.031772 | val_sign_acc=0.517 ← best
# Epoch 07/30 | train_loss=0.000980 | val_MAE=0.030381 | val_sign_acc=0.516 ← best
# Epoch 05/30 | train_loss=0.001126 | val_MAE=0.033200 | val_sign_acc=0.517 ← best
# Epoch 06/30 | train_loss=0.001021 | val_MAE=0.031772 | val_sign_acc=0.517 ← best
# Epoch 07/30 | train_loss=0.000980 | val_MAE=0.030381 | val_sign_acc=0.516 ← best
# Epoch 08/30 | train_loss=0.000941 | val_MAE=0.029042 | val_sign_acc=0.516 ← best
# Epoch 09/30 | train_loss=0.000879 | val_MAE=0.027758 | val_sign_acc=0.516 ← best
# Epoch 10/30 | train_loss=0.000868 | val_MAE=0.026536 | val_sign_acc=0.514 ← best
# Epoch 08/30 | train_loss=0.000941 | val_MAE=0.029042 | val_sign_acc=0.516 ← best
# Epoch 09/30 | train_loss=0.000879 | val_MAE=0.027758 | val_sign_acc=0.516 ← best
# Epoch 10/30 | train_loss=0.000868 | val_MAE=0.026536 | val_sign_acc=0.514 ← best
# Epoch 11/30 | train_loss=0.000809 | val_MAE=0.025380 | val_sign_acc=0.518 ← best
# Epoch 12/30 | train_loss=0.000746 | val_MAE=0.024276 | val_sign_acc=0.513 ← best
# Epoch 13/30 | train_loss=0.000719 | val_MAE=0.023241 | val_sign_acc=0.514 ← best
# Epoch 11/30 | train_loss=0.000809 | val_MAE=0.025380 | val_sign_acc=0.518 ← best
# Epoch 12/30 | train_loss=0.000746 | val_MAE=0.024276 | val_sign_acc=0.513 ← best
# Epoch 13/30 | train_loss=0.000719 | val_MAE=0.023241 | val_sign_acc=0.514 ← best
# Epoch 14/30 | train_loss=0.000678 | val_MAE=0.022278 | val_sign_acc=0.513 ← best
# Epoch 15/30 | train_loss=0.000660 | val_MAE=0.021380 | val_sign_acc=0.511 ← best
# Epoch 16/30 | train_loss=0.000642 | val_MAE=0.020547 | val_sign_acc=0.511 ← best
# Epoch 14/30 | train_loss=0.000678 | val_MAE=0.022278 | val_sign_acc=0.513 ← best
# Epoch 15/30 | train_loss=0.000660 | val_MAE=0.021380 | val_sign_acc=0.511 ← best
# Epoch 16/30 | train_loss=0.000642 | val_MAE=0.020547 | val_sign_acc=0.511 ← best
# Epoch 17/30 | train_loss=0.000605 | val_MAE=0.019766 | val_sign_acc=0.510 ← best
# Epoch 18/30 | train_loss=0.000596 | val_MAE=0.019079 | val_sign_acc=0.517 ← best
# Epoch 19/30 | train_loss=0.000579 | val_MAE=0.018551 | val_sign_acc=0.521 ← best
# Epoch 17/30 | train_loss=0.000605 | val_MAE=0.019766 | val_sign_acc=0.510 ← best
# Epoch 18/30 | train_loss=0.000596 | val_MAE=0.019079 | val_sign_acc=0.517 ← best
# Epoch 19/30 | train_loss=0.000579 | val_MAE=0.018551 | val_sign_acc=0.521 ← best
# Epoch 20/30 | train_loss=0.000595 | val_MAE=0.018164 | val_sign_acc=0.521 ← best
# Epoch 21/30 | train_loss=0.000562 | val_MAE=0.017875 | val_sign_acc=0.523 ← best
# Epoch 22/30 | train_loss=0.000543 | val_MAE=0.017656 | val_sign_acc=0.518 ← best
# Epoch 20/30 | train_loss=0.000595 | val_MAE=0.018164 | val_sign_acc=0.521 ← best
# Epoch 21/30 | train_loss=0.000562 | val_MAE=0.017875 | val_sign_acc=0.523 ← best
# Epoch 22/30 | train_loss=0.000543 | val_MAE=0.017656 | val_sign_acc=0.518 ← best
# Epoch 23/30 | train_loss=0.000554 | val_MAE=0.017489 | val_sign_acc=0.526 ← best
# Epoch 24/30 | train_loss=0.000529 | val_MAE=0.017367 | val_sign_acc=0.517 ← best
# Epoch 25/30 | train_loss=0.000523 | val_MAE=0.017271 | val_sign_acc=0.517 ← best
# Epoch 23/30 | train_loss=0.000554 | val_MAE=0.017489 | val_sign_acc=0.526 ← best
# Epoch 24/30 | train_loss=0.000529 | val_MAE=0.017367 | val_sign_acc=0.517 ← best
# Epoch 25/30 | train_loss=0.000523 | val_MAE=0.017271 | val_sign_acc=0.517 ← best
# Epoch 26/30 | train_loss=0.000514 | val_MAE=0.017197 | val_sign_acc=0.506 ← best
# Epoch 27/30 | train_loss=0.000513 | val_MAE=0.017138 | val_sign_acc=0.503 ← best
# Epoch 28/30 | train_loss=0.000541 | val_MAE=0.017090 | val_sign_acc=0.501 ← best
# Epoch 26/30 | train_loss=0.000514 | val_MAE=0.017197 | val_sign_acc=0.506 ← best
# Epoch 27/30 | train_loss=0.000513 | val_MAE=0.017138 | val_sign_acc=0.503 ← best
# Epoch 28/30 | train_loss=0.000541 | val_MAE=0.017090 | val_sign_acc=0.501 ← best
# Epoch 29/30 | train_loss=0.000506 | val_MAE=0.017050 | val_sign_acc=0.490 ← best
# Epoch 30/30 | train_loss=0.000528 | val_MAE=0.017015 | val_sign_acc=0.489 ← best
# Epoch 29/30 | train_loss=0.000506 | val_MAE=0.017050 | val_sign_acc=0.490 ← best
# Epoch 30/30 | train_loss=0.000528 | val_MAE=0.017015 | val_sign_acc=0.489 ← best
#
# ================================================================================
# FINAL RESULTS:
#   Val:  MAE=0.017015 | Sign Acc=0.489
#   Test: MAE=0.036239 | Sign Acc=0.519
# ================================================================================
#
# ================================================================================
# PnL Analysis (price-space, mark-to-market)
# ================================================================================
#
# Best VAL threshold (price space): 0.000000
#   sum_pnl=0.034500 | trade_rate=1.000 | hit_rate=0.489
#
# VAL  PnL: {'n_samples': 704.0, 'n_trades': 704.0, 'trade_rate': 1.0, 'avg_pnl': 4.900568181818189e-05, 'sum_pnl': 0.03450000000000005, 'median_pnl': -0.0004999999999999935, 'hit_rate_on_trades': 0.48863636363636365}
# TEST PnL: {'n_samples': 5299.0, 'n_trades': 5299.0, 'trade_rate': 1.0, 'avg_pnl': 6.595584072466504e-05, 'sum_pnl': 0.3495000000000001, 'median_pnl': 0.0004999999999999987, 'hit_rate_on_trades': 0.5185884129080959}
# ================================================================================
# ✓ Model saved to: ../IEOR4212/exploration/datasets/market_253703/move_reg/checkpoints/mamba_regressor.pt
#
# ================================================================================
# Training LSTM Baseline: 253703
# ================================================================================
# Shapes: X_train=(727, 64, 8) X_val=(704, 64, 8) X_test=(5300, 64, 8)
# Features: 8 | seq_len: 64
# Device: cuda
#
# ================================================================================
# FINAL RESULTS:
#   Val:  MAE=0.017015 | Sign Acc=0.489
#   Test: MAE=0.036239 | Sign Acc=0.519
# ================================================================================
#
# ================================================================================
# PnL Analysis (price-space, mark-to-market)
# ================================================================================
#
# Best VAL threshold (price space): 0.000000
#   sum_pnl=0.034500 | trade_rate=1.000 | hit_rate=0.489
#
# VAL  PnL: {'n_samples': 704.0, 'n_trades': 704.0, 'trade_rate': 1.0, 'avg_pnl': 4.900568181818189e-05, 'sum_pnl': 0.03450000000000005, 'median_pnl': -0.0004999999999999935, 'hit_rate_on_trades': 0.48863636363636365}
# TEST PnL: {'n_samples': 5299.0, 'n_trades': 5299.0, 'trade_rate': 1.0, 'avg_pnl': 6.595584072466504e-05, 'sum_pnl': 0.3495000000000001, 'median_pnl': 0.0004999999999999987, 'hit_rate_on_trades': 0.5185884129080959}
# ================================================================================
# ✓ Model saved to: ../IEOR4212/exploration/datasets/market_253703/move_reg/checkpoints/mamba_regressor.pt
#
# ================================================================================
# Training LSTM Baseline: 253703
# ================================================================================
# Shapes: X_train=(727, 64, 8) X_val=(704, 64, 8) X_test=(5300, 64, 8)
# Features: 8 | seq_len: 64
# Device: cuda
# Epoch 01/30 | train_loss=0.002239 | val_MAE=0.056500 | val_sign_acc=0.483 ← best
# Epoch 01/30 | train_loss=0.002239 | val_MAE=0.056500 | val_sign_acc=0.483 ← best
# Epoch 05/30 | train_loss=0.001401 | val_MAE=0.038800 | val_sign_acc=0.483 ← best
# Epoch 05/30 | train_loss=0.001401 | val_MAE=0.038800 | val_sign_acc=0.483 ← best
# Epoch 10/30 | train_loss=0.000822 | val_MAE=0.021749 | val_sign_acc=0.483 ← best
# Epoch 10/30 | train_loss=0.000822 | val_MAE=0.021749 | val_sign_acc=0.483 ← best
# Epoch 15/30 | train_loss=0.000676 | val_MAE=0.016316 | val_sign_acc=0.521 ← best
# Epoch 15/30 | train_loss=0.000676 | val_MAE=0.016316 | val_sign_acc=0.521 ← best
# Epoch 20/30 | train_loss=0.000619 | val_MAE=0.016052 | val_sign_acc=0.560 ← best
# Epoch 20/30 | train_loss=0.000619 | val_MAE=0.016052 | val_sign_acc=0.560 ← best
# Epoch 25/30 | train_loss=0.000610 | val_MAE=0.016097 | val_sign_acc=0.555
# Early stopping (no val MAE improvement for 7 epochs).
# Epoch 25/30 | train_loss=0.000610 | val_MAE=0.016097 | val_sign_acc=0.555
# Early stopping (no val MAE improvement for 7 epochs).
#
# ================================================================================
# LSTM FINAL RESULTS:
#   Val:  MAE=0.016052 | Sign Acc=0.560
#   Test: MAE=0.034760 | Sign Acc=0.503
# ================================================================================
#
# ================================================================================
# LSTM PnL Analysis
# ================================================================================
#
# Best VAL threshold: 0.000000
#   sum_pnl=0.101500 | trade_rate=1.000 | hit_rate=0.560
#
# VAL  PnL: {'n_samples': 704.0, 'n_trades': 704.0, 'trade_rate': 1.0, 'avg_pnl': 0.00014417613636363632, 'sum_pnl': 0.10149999999999998, 'median_pnl': 0.0005000000000000004, 'hit_rate_on_trades': 0.5596590909090909}
# TEST PnL: {'n_samples': 5299.0, 'n_trades': 5299.0, 'trade_rate': 1.0, 'avg_pnl': 8.426118135497266e-05, 'sum_pnl': 0.4465000000000002, 'median_pnl': 0.0004999999999999935, 'hit_rate_on_trades': 0.5027363653519532}
# ================================================================================
# ✓ LSTM model saved to: ../IEOR4212/exploration/datasets/market_253703/move_reg/checkpoints/lstm_regressor.pt
#
# ################################################################################
# # Market: 253874
# ################################################################################
#
# ❌ [SKIP MAMBA] 253874
# Error: Dataset path not found: ../IEOR4212/exploration/datasets/market_253874/move_reg
# Traceback:
# Traceback (most recent call last):
#   File "/tmp/ipykernel_21251/778852393.py", line 17, in <module>
#     val_mae, test_mae, val_sign, test_sign, val_pnl, test_pnl = train_one_market(
#                                                                 ~~~~~~~~~~~~~~~~^
#         market_id=market_id,
#         ^^^^^^^^^^^^^^^^^^^^
#     ...<8 lines>...
#         grad_clip=GRAD_CLIP,
#         ^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/tmp/ipykernel_21251/1554684940.py", line 16, in train_one_market
#     X_train, y_train, X_val, y_val, X_test, y_test, meta, ev, end_idx_train, end_idx_val, end_idx_test = load_market_dataset(ds_dir)
#                                                                                                          ~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/tmp/ipykernel_21251/3009146076.py", line 6, in load_market_dataset
#     raise FileNotFoundError(f"Dataset path not found: {data_path}")
# FileNotFoundError: Dataset path not found: ../IEOR4212/exploration/datasets/market_253874/move_reg
#
#
# ❌ [SKIP LSTM] 253874
# Error: Dataset path not found: ../IEOR4212/exploration/datasets/market_253874/move_reg
# Traceback:
# Traceback (most recent call last):
#   File "/tmp/ipykernel_21251/778852393.py", line 42, in <module>
#     val_mae_lstm, test_mae_lstm, val_sign_lstm, test_sign_lstm, val_pnl_lstm, test_pnl_lstm = train_lstm_baseline(
#                                                                                               ~~~~~~~~~~~~~~~~~~~^
#         market_id=market_id,
#         ^^^^^^^^^^^^^^^^^^^^
#     ...<8 lines>...
#         grad_clip=GRAD_CLIP,
#         ^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/tmp/ipykernel_21251/459375583.py", line 16, in train_lstm_baseline
#     X_train, y_train, X_val, y_val, X_test, y_test, meta, ev, end_idx_train, end_idx_val, end_idx_test = load_market_dataset(ds_dir)
#                                                                                                          ~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/tmp/ipykernel_21251/3009146076.py", line 6, in load_market_dataset
#     raise FileNotFoundError(f"Dataset path not found: {data_path}")
# FileNotFoundError: Dataset path not found: ../IEOR4212/exploration/datasets/market_253874/move_reg
#
#
# ================================================================================
# ALL TRAINING COMPLETE
# ================================================================================
# Mamba: 39/58 successful
# LSTM:  35/58 successful
#
# ================================================================================
# LSTM FINAL RESULTS:
#   Val:  MAE=0.016052 | Sign Acc=0.560
#   Test: MAE=0.034760 | Sign Acc=0.503
# ================================================================================
#
# ================================================================================
# LSTM PnL Analysis
# ================================================================================
#
# Best VAL threshold: 0.000000
#   sum_pnl=0.101500 | trade_rate=1.000 | hit_rate=0.560
#
# VAL  PnL: {'n_samples': 704.0, 'n_trades': 704.0, 'trade_rate': 1.0, 'avg_pnl': 0.00014417613636363632, 'sum_pnl': 0.10149999999999998, 'median_pnl': 0.0005000000000000004, 'hit_rate_on_trades': 0.5596590909090909}
# TEST PnL: {'n_samples': 5299.0, 'n_trades': 5299.0, 'trade_rate': 1.0, 'avg_pnl': 8.426118135497266e-05, 'sum_pnl': 0.4465000000000002, 'median_pnl': 0.0004999999999999935, 'hit_rate_on_trades': 0.5027363653519532}
# ================================================================================
# ✓ LSTM model saved to: ../IEOR4212/exploration/datasets/market_253703/move_reg/checkpoints/lstm_regressor.pt
#
# ################################################################################
# # Market: 253874
# ################################################################################
#
# ❌ [SKIP MAMBA] 253874
# Error: Dataset path not found: ../IEOR4212/exploration/datasets/market_253874/move_reg
# Traceback:
# Traceback (most recent call last):
#   File "/tmp/ipykernel_21251/778852393.py", line 17, in <module>
#     val_mae, test_mae, val_sign, test_sign, val_pnl, test_pnl = train_one_market(
#                                                                 ~~~~~~~~~~~~~~~~^
#         market_id=market_id,
#         ^^^^^^^^^^^^^^^^^^^^
#     ...<8 lines>...
#         grad_clip=GRAD_CLIP,
#         ^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/tmp/ipykernel_21251/1554684940.py", line 16, in train_one_market
#     X_train, y_train, X_val, y_val, X_test, y_test, meta, ev, end_idx_train, end_idx_val, end_idx_test = load_market_dataset(ds_dir)
#                                                                                                          ~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/tmp/ipykernel_21251/3009146076.py", line 6, in load_market_dataset
#     raise FileNotFoundError(f"Dataset path not found: {data_path}")
# FileNotFoundError: Dataset path not found: ../IEOR4212/exploration/datasets/market_253874/move_reg
#
#
# ❌ [SKIP LSTM] 253874
# Error: Dataset path not found: ../IEOR4212/exploration/datasets/market_253874/move_reg
# Traceback:
# Traceback (most recent call last):
#   File "/tmp/ipykernel_21251/778852393.py", line 42, in <module>
#     val_mae_lstm, test_mae_lstm, val_sign_lstm, test_sign_lstm, val_pnl_lstm, test_pnl_lstm = train_lstm_baseline(
#                                                                                               ~~~~~~~~~~~~~~~~~~~^
#         market_id=market_id,
#         ^^^^^^^^^^^^^^^^^^^^
#     ...<8 lines>...
#         grad_clip=GRAD_CLIP,
#         ^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/tmp/ipykernel_21251/459375583.py", line 16, in train_lstm_baseline
#     X_train, y_train, X_val, y_val, X_test, y_test, meta, ev, end_idx_train, end_idx_val, end_idx_test = load_market_dataset(ds_dir)
#                                                                                                          ~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/tmp/ipykernel_21251/3009146076.py", line 6, in load_market_dataset
#     raise FileNotFoundError(f"Dataset path not found: {data_path}")
# FileNotFoundError: Dataset path not found: ../IEOR4212/exploration/datasets/market_253874/move_reg
#
#
# ================================================================================
# ALL TRAINING COMPLETE
# ================================================================================
# Mamba: 39/58 successful
# LSTM:  35/58 successful

# %% [markdown]
# ## Summary Results

# %%
# Filter out failed runs
mamba_valid = [(m, vm, tm, vs, ts, vp, tp) for m, vm, tm, vs, ts, vp, tp in mamba_results if vm is not None]
lstm_valid = [(m, vm, tm, vs, ts, vp, tp) for m, vm, tm, vs, ts, vp, tp in lstm_results if vm is not None]

if mamba_valid and lstm_valid:
    print("\n" + "="*120)
    print("COMPARISON: Mamba vs LSTM")
    print("="*120)
    print(f"{'Market':<12s} | {'Mamba MAE':>10s} | {'LSTM MAE':>10s} | {'Mamba Sign':>11s} | {'LSTM Sign':>11s} | {'Mamba PnL':>10s} | {'LSTM PnL':>10s} | {'Winner':>8s}")
    print("-"*120)
    
    mamba_wins_mae = 0
    lstm_wins_mae = 0
    mamba_wins_pnl = 0
    lstm_wins_pnl = 0
    
    # Create lookup dictionaries
    mamba_dict = {m: (vm, tm, vs, ts, vp, tp) for m, vm, tm, vs, ts, vp, tp in mamba_valid}
    lstm_dict = {m: (vm, tm, vs, ts, vp, tp) for m, vm, tm, vs, ts, vp, tp in lstm_valid}
    
    # Compare markets that have both results
    common_markets = set(mamba_dict.keys()) & set(lstm_dict.keys())
    
    for mid in sorted(common_markets):
        m_val_mae, m_test_mae, m_val_sign, m_test_sign, m_val_pnl, m_test_pnl = mamba_dict[mid]
        l_val_mae, l_test_mae, l_val_sign, l_test_sign, l_val_pnl, l_test_pnl = lstm_dict[mid]
        
        # Extract test sum_pnl
        m_test_sum_pnl = m_test_pnl.get('sum_pnl', 0.0)
        l_test_sum_pnl = l_test_pnl.get('sum_pnl', 0.0)
        
        # Winner based on test sum_pnl (higher is better)
        winner = "Mamba" if m_test_sum_pnl > l_test_sum_pnl else "LSTM"
        if m_test_mae < l_test_mae:
            mamba_wins_mae += 1
        else:
            lstm_wins_mae += 1
        
        if m_test_sum_pnl > l_test_sum_pnl:
            mamba_wins_pnl += 1
        else:
            lstm_wins_pnl += 1
        
        print(f"{mid:<12s} | {m_test_mae:10.6f} | {l_test_mae:10.6f} | {m_test_sign:11.3f} | {l_test_sign:11.3f} | {m_test_sum_pnl:10.5f} | {l_test_sum_pnl:10.5f} | {winner:>8s}")
    
    print("-"*120)
    
    # Overall statistics
    mamba_avg_test_mae = np.mean([mamba_dict[m][1] for m in common_markets])
    lstm_avg_test_mae = np.mean([lstm_dict[m][1] for m in common_markets])
    
    mamba_avg_sign = np.mean([mamba_dict[m][3] for m in common_markets])
    lstm_avg_sign = np.mean([lstm_dict[m][3] for m in common_markets])
    
    mamba_avg_pnl = np.mean([mamba_dict[m][5].get('sum_pnl', 0.0) for m in common_markets])
    lstm_avg_pnl = np.mean([lstm_dict[m][5].get('sum_pnl', 0.0) for m in common_markets])
    
    print(f"{'MAMBA AVG':<12s} | {mamba_avg_test_mae:10.6f} | {'---':>10s} | {mamba_avg_sign:11.3f} | {'---':>11s} | {mamba_avg_pnl:10.5f} | {'---':>10s} | {'':<8s}")
    print(f"{'LSTM AVG':<12s} | {'---':>10s} | {lstm_avg_test_mae:10.6f} | {'---':>11s} | {lstm_avg_sign:11.3f} | {'---':>10s} | {lstm_avg_pnl:10.5f} | {'':<8s}")
    print("="*120)
    
    print(f"\n📊 SUMMARY:")
    print(f"\n  Test MAE (lower is better):")
    print(f"    Mamba wins: {mamba_wins_mae}/{len(common_markets)} markets ({100*mamba_wins_mae/len(common_markets):.1f}%)")
    print(f"    LSTM wins:  {lstm_wins_mae}/{len(common_markets)} markets ({100*lstm_wins_mae/len(common_markets):.1f}%)")
    print(f"    Average improvement: {100*(lstm_avg_test_mae - mamba_avg_test_mae)/lstm_avg_test_mae:+.2f}% (Mamba vs LSTM)")
    
    print(f"\n  Test PnL (higher is better):")
    print(f"    Mamba wins: {mamba_wins_pnl}/{len(common_markets)} markets ({100*mamba_wins_pnl/len(common_markets):.1f}%)")
    print(f"    LSTM wins:  {lstm_wins_pnl}/{len(common_markets)} markets ({100*lstm_wins_pnl/len(common_markets):.1f}%)")
    print(f"    Mamba avg test PnL: {mamba_avg_pnl:+.5f}")
    print(f"    LSTM avg test PnL:  {lstm_avg_pnl:+.5f}")
    
    print(f"\n  Test sign accuracy:")
    print(f"    Mamba: {mamba_avg_sign:.3f}")
    print(f"    LSTM:  {lstm_avg_sign:.3f}")
    
    # Detailed PnL metrics
    mamba_avg_hit = np.mean([mamba_dict[m][5].get('hit_rate_on_trades', 0.0) for m in common_markets])
    lstm_avg_hit = np.mean([lstm_dict[m][5].get('hit_rate_on_trades', 0.0) for m in common_markets])
    mamba_avg_trade_rate = np.mean([mamba_dict[m][5].get('trade_rate', 0.0) for m in common_markets])
    lstm_avg_trade_rate = np.mean([lstm_dict[m][5].get('trade_rate', 0.0) for m in common_markets])
    
    print(f"\n  Trading metrics:")
    print(f"    Mamba: hit_rate={mamba_avg_hit:.3f} | trade_rate={mamba_avg_trade_rate:.3f}")
    print(f"    LSTM:  hit_rate={lstm_avg_hit:.3f} | trade_rate={lstm_avg_trade_rate:.3f}")
    
elif mamba_valid:
    print("\n⚠ Only Mamba results available (LSTM training failed or skipped)")
    print(f"Trained {len(mamba_valid)} markets successfully with Mamba")
elif lstm_valid:
    print("\n⚠ Only LSTM results available (Mamba training failed or skipped)")
    print(f"Trained {len(lstm_valid)} markets successfully with LSTM")
else:
    print("\n⚠ No markets were successfully trained")
# Out:
# ========================================================================================================================
# COMPARISON: Mamba vs LSTM
# ========================================================================================================================
# Market       |  Mamba MAE |   LSTM MAE |  Mamba Sign |   LSTM Sign |  Mamba PnL |   LSTM PnL |   Winner
# ------------------------------------------------------------------------------------------------------------------------
# 253592       |   0.073317 |   0.078690 |       0.509 |       0.504 |    0.61050 |    0.15000 |    Mamba
# 253593       |   0.331463 |   0.364242 |       0.754 |       0.465 |    0.05450 |   -0.00250 |    Mamba
# 253594       |   0.064360 |   0.069023 |       0.529 |       0.536 |   -0.08250 |    0.08150 |     LSTM
# 253595       |   0.217240 |   0.220299 |       0.499 |       0.476 |   -0.00200 |   -0.01000 |    Mamba
# 253596       |   1.426464 |   1.458275 |       0.750 |       0.500 |    0.00200 |   -0.00100 |    Mamba
# 253598       |   0.611074 |   0.631006 |       0.796 |       0.490 |    0.01750 |    0.00000 |    Mamba
# 253609       |   0.115777 |   0.119860 |       0.501 |       0.495 |   -0.00700 |   -0.00500 |     LSTM
# 253610       |   0.688105 |   0.712544 |       0.765 |       0.510 |    0.03700 |    0.00000 |    Mamba
# 253635       |   0.870721 |   0.872034 |       0.500 |       0.500 |    0.00100 |    0.00000 |    Mamba
# 253639       |   0.726647 |   0.741719 |       0.729 |       0.571 |    0.02550 |    0.00000 |    Mamba
# 253641       |   0.220058 |   0.242758 |       0.588 |       0.469 |    0.00000 |    0.00000 |     LSTM
# 253642       |   0.153485 |   0.169880 |       0.573 |       0.550 |    0.01250 |    0.03200 |     LSTM
# 253697       |   0.045127 |   0.043789 |       0.496 |       0.494 |    0.04250 |    0.34600 |     LSTM
# 253702       |   0.115320 |   0.101474 |       0.508 |       0.530 |   -0.02800 |    0.11100 |     LSTM
# 253703       |   0.036239 |   0.034760 |       0.519 |       0.503 |    0.34950 |    0.44650 |     LSTM
# 253706       |   0.014237 |   0.016325 |       0.525 |       0.524 |    0.01000 |    0.28100 |     LSTM
# 253723       |   1.060311 |   1.097973 |       1.000 |       0.500 |    0.00700 |   -0.00100 |    Mamba
# 253724       |   0.997191 |   0.992259 |       0.444 |       0.444 |    0.00000 |    0.00000 |     LSTM
# 253725       |   0.156880 |   0.165679 |       0.536 |       0.470 |    0.03200 |   -0.01950 |    Mamba
# 253728       |   0.824654 |   0.852144 |       0.544 |       0.513 |    0.01300 |    0.00500 |    Mamba
# 253730       |   0.156551 |   0.160303 |       0.490 |       0.630 |   -0.00150 |    0.12550 |     LSTM
# 253731       |   0.295305 |   0.311618 |       0.542 |       0.483 |    0.00000 |    0.00000 |     LSTM
# 253736       |   0.165949 |   0.175798 |       0.588 |       0.504 |    0.00000 |    0.00000 |     LSTM
# 253737       |   0.288571 |   0.312110 |       0.523 |       0.531 |    0.00450 |    0.00650 |     LSTM
# 538928       |   0.334077 |   0.136194 |       0.504 |       0.466 |    0.02650 |    0.00000 |    Mamba
# 538929       |   0.023272 |   0.023087 |       0.502 |       0.487 |   -0.01400 |   -0.04050 |    Mamba
# 538930       |   0.146747 |   0.168429 |       0.743 |       0.636 |    0.12350 |    0.06750 |    Mamba
# 538931       |   0.570906 |   0.758698 |       0.682 |       0.455 |    0.00150 |   -0.00250 |    Mamba
# 538932       |   0.023413 |   0.016474 |       0.483 |       0.513 |    0.00300 |   -0.03050 |    Mamba
# 538933       |   0.601730 |   0.631379 |       0.476 |       0.857 |    0.00000 |    0.01100 |     LSTM
# 538934       |   0.683764 |   0.694585 |       0.571 |       0.548 |    0.00100 |    0.00050 |    Mamba
# 538935       |   0.339604 |   0.396199 |       0.577 |       0.481 |    0.00750 |   -0.00050 |    Mamba
# 538936       |   0.712161 |   0.690570 |       0.476 |       0.524 |   -0.00450 |    0.00150 |     LSTM
# 538937       |   0.736568 |   0.836721 |       0.480 |       0.480 |    0.00000 |    0.00000 |     LSTM
# 538938       |   0.883770 |   0.862562 |       0.474 |       0.526 |   -0.00350 |   -0.00050 |     LSTM
# ------------------------------------------------------------------------------------------------------------------------
# MAMBA AVG    |   0.420316 |        --- |       0.576 |         --- |    0.03540 |        --- |
# LSTM AVG     |        --- |   0.433127 |         --- |       0.519 |        --- |    0.04434 |
# ========================================================================================================================
#
# 📊 SUMMARY:
#
#   Test MAE (lower is better):
#     Mamba wins: 26/35 markets (74.3%)
#     LSTM wins:  9/35 markets (25.7%)
#     Average improvement: +2.96% (Mamba vs LSTM)
#
#   Test PnL (higher is better):
#     Mamba wins: 18/35 markets (51.4%)
#     LSTM wins:  17/35 markets (48.6%)
#     Mamba avg test PnL: +0.03540
#     LSTM avg test PnL:  +0.04434
#
#   Test sign accuracy:
#     Mamba: 0.576
#     LSTM:  0.519
#
#   Trading metrics:
#     Mamba: hit_rate=0.496 | trade_rate=0.611
#     LSTM:  hit_rate=0.377 | trade_rate=0.669

# %% [markdown]
# ## Interpretation
#
# **Models:**
# - **Mamba**: State-space model with selective attention (faster, more parameter efficient)
# - **LSTM**: Standard 2-layer LSTM baseline
#
# **Metrics:**
# - **MAE (Mean Absolute Error)**: Average absolute difference between predicted and actual logit changes (lower is better)
# - **Sign Accuracy**: Percentage of times the model correctly predicts the direction (up/down)
# - **PnL (Profit & Loss)**: Mark-to-market returns using optimal threshold from validation set
#
# **Good performance:**
# - Sign accuracy > 0.55 (better than random 0.50)
# - Positive sum_pnl with reasonable trade_rate (0.3-0.7)
# - hit_rate_on_trades > 0.55
#
# **What to look for:**
# - If Mamba consistently wins: State-space modeling captures price dynamics better than LSTM
# - If LSTM wins: Sequential dependencies may be more important than selective attention
# - Similar performance: Both architectures adequate, consider simpler model for production
#
# **PnL interpretation:**
# - `sum_pnl > 0`: Model has directional edge
# - `hit_rate_on_trades > 0.55`: Better than random coin flip
# - `trade_rate`: Fraction of samples where |predicted_dp| > threshold (too low = undertrading, too high = overtrading)
